# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    #There are several ways to normalize the data. Here I choose the simple method : (x - min(X)) / (max(X) - min(x))
    
    image_normalize = np.zeros((len(x),32,32,3))
    m = 0
    for image in x:
        for i in range(3):
            image_ = image[:,:,i]
            image_max = np.max(np.max(image_))
            image_min = np.max(np.min(image_))
            image[:,:,i] = (image_ - image_min) / float(image_max - image_min)
        image_normalize[m,:,:,:] = image
        m += 1
    return image_normalize
        
            

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    from sklearn.preprocessing import OneHotEncoder
    one_hot_encode = OneHotEncoder().fit(np.arange(10).reshape(-1,1))
    one_hot_out = one_hot_encode.transform(np.array(x).reshape(-1,1)).toarray()
    return one_hot_out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, shape=[None, n_classes], name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, name='keep_prob' )
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3],
                                            conv_num_outputs], stddev=0.05))
    biases = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, biases)
    conv_layer = tf.nn.relu(conv_layer)
    pool_layer = tf.nn.max_pool(conv_layer, ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                                strides=[1, pool_strides[0],pool_strides[1], 1], padding='SAME')
    
    
    return pool_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    layer_shape = x_tensor.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(x_tensor, [-1, num_features])
    
    return layer_flat


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.random_normal(shape=[x_tensor.get_shape().as_list()[1], num_outputs]))
    biases = tf.Variable(tf.zeros(num_outputs))
    fully_conn = tf.add(tf.matmul(x_tensor, weights), biases)
    fully_conn = tf.nn.relu(fully_conn)
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.random_normal(shape=[x_tensor.get_shape().as_list()[1], num_outputs]))
    biases = tf.Variable(tf.zeros(num_outputs))
    logits = tf.add(tf.matmul(x_tensor, weights), biases)
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv_1 = conv2d_maxpool(x, 16, conv_ksize=[5,5], conv_strides=[1,1], pool_ksize=[2,2], pool_strides=[2,2])
    conv_1 = tf.nn.dropout(conv_1, keep_prob)
    conv_2 = conv2d_maxpool(conv_1, 36, conv_ksize=[5,5], conv_strides=[1,1], pool_ksize=[2,2], pool_strides=[2,2])
#     conv_2 = tf.nn.dropout(conv_2, keep_prob)
#     conv_3 = conv2d_maxpool(conv_2, 32, conv_ksize=[5,5], conv_strides=[1,1], pool_ksize=[2,2], pool_strides=[2,2])
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(conv_2)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_conn_layer = fully_conn(flatten_layer, 128)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    logits = output(fully_conn_layer, 10)
    
    # TODO: return output
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print('The Validation Cost is ' + str(sess.run(cost, 
                                                   feed_dict={x:feature_batch, y:label_batch, keep_prob:1.})))
    print('The Validation Accuracy is ' + str(session.run(accuracy, 
                                                          feed_dict={x:feature_batch, y:label_batch, keep_prob:1.})))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  The Validation Cost is 2.29065
# The Validation Accuracy is 0.125
# Epoch  2, CIFAR-10 Batch 1:  The Validation Cost is 2.28827
# The Validation Accuracy is 0.125
# Epoch  3, CIFAR-10 Batch 1:  The Validation Cost is 2.28074
# The Validation Accuracy is 0.175
# Epoch  4, CIFAR-10 Batch 1:  The Validation Cost is 2.28082
# The Validation Accuracy is 0.125
# Epoch  5, CIFAR-10 Batch 1:  The Validation Cost is 2.23405
# The Validation Accuracy is 0.15
# Epoch  6, CIFAR-10 Batch 1:  The Validation Cost is 2.21354
# The Validation Accuracy is 0.2
# Epoch  7, CIFAR-10 Batch 1:  The Validation Cost is 2.19767
# The Validation Accuracy is 0.2
# Epoch  8, CIFAR-10 Batch 1:  The Validation Cost is 2.17161
# The Validation Accuracy is 0.2
# Epoch  9, CIFAR-10 Batch 1:  The Validation Cost is 2.10964
# The Validation Accuracy is 0.225
# Epoch 10, CIFAR-10 Batch 1:  The Validation Cost is 2.10599
# The Validation Accuracy is 0.275
# Epoch 11, CIFAR-10 Batch 1:  The Validation Cost is 2.06293
# The Validation Accuracy is 0.25
# Epoch 12, CIFAR-10 Batch 1:  The Validation Cost is 2.05849
# The Validation Accuracy is 0.275
# Epoch 13, CIFAR-10 Batch 1:  The Validation Cost is 1.97327
# The Validation Accuracy is 0.325
# Epoch 14, CIFAR-10 Batch 1:  The Validation Cost is 1.94567
# The Validation Accuracy is 0.35
# Epoch 15, CIFAR-10 Batch 1:  The Validation Cost is 1.92379
# The Validation Accuracy is 0.4
# Epoch 16, CIFAR-10 Batch 1:  The Validation Cost is 1.8515
# The Validation Accuracy is 0.475
# Epoch 17, CIFAR-10 Batch 1:  The Validation Cost is 1.85953
# The Validation Accuracy is 0.45
# Epoch 18, CIFAR-10 Batch 1:  The Validation Cost is 1.80928
# The Validation Accuracy is 0.45
# Epoch 19, CIFAR-10 Batch 1:  The Validation Cost is 1.75908
# The Validation Accuracy is 0.45
# Epoch 20, CIFAR-10 Batch 1:  The Validation Cost is 1.71379
# The Validation Accuracy is 0.475
# Epoch 21, CIFAR-10 Batch 1:  The Validation Cost is 1.70834
# The Validation Accuracy is 0.5
# Epoch 22, CIFAR-10 Batch 1:  The Validation Cost is 1.65622
# The Validation Accuracy is 0.5
# Epoch 23, CIFAR-10 Batch 1:  The Validation Cost is 1.60398
# The Validation Accuracy is 0.525
# Epoch 24, CIFAR-10 Batch 1:  The Validation Cost is 1.57016
# The Validation Accuracy is 0.525
# Epoch 25, CIFAR-10 Batch 1:  The Validation Cost is 1.56697
# The Validation Accuracy is 0.525
# Epoch 26, CIFAR-10 Batch 1:  The Validation Cost is 1.53622
# The Validation Accuracy is 0.5
# Epoch 27, CIFAR-10 Batch 1:  The Validation Cost is 1.49141
# The Validation Accuracy is 0.525
# Epoch 28, CIFAR-10 Batch 1:  The Validation Cost is 1.47213
# The Validation Accuracy is 0.575
# Epoch 29, CIFAR-10 Batch 1:  The Validation Cost is 1.44163
# The Validation Accuracy is 0.55
# Epoch 30, CIFAR-10 Batch 1:  The Validation Cost is 1.40481
# The Validation Accuracy is 0.65
# Epoch 31, CIFAR-10 Batch 1:  The Validation Cost is 1.38477
# The Validation Accuracy is 0.6
# Epoch 32, CIFAR-10 Batch 1:  The Validation Cost is 1.3526
# The Validation Accuracy is 0.625
# Epoch 33, CIFAR-10 Batch 1:  The Validation Cost is 1.33679
# The Validation Accuracy is 0.65
# Epoch 34, CIFAR-10 Batch 1:  The Validation Cost is 1.30546
# The Validation Accuracy is 0.625
# Epoch 35, CIFAR-10 Batch 1:  The Validation Cost is 1.21339
# The Validation Accuracy is 0.7
# Epoch 36, CIFAR-10 Batch 1:  The Validation Cost is 1.21584
# The Validation Accuracy is 0.725
# Epoch 37, CIFAR-10 Batch 1:  The Validation Cost is 1.19065
# The Validation Accuracy is 0.75
# Epoch 38, CIFAR-10 Batch 1:  The Validation Cost is 1.15931
# The Validation Accuracy is 0.675
# Epoch 39, CIFAR-10 Batch 1:  The Validation Cost is 1.08037
# The Validation Accuracy is 0.8
# Epoch 40, CIFAR-10 Batch 1:  The Validation Cost is 1.13981
# The Validation Accuracy is 0.8
# Epoch 41, CIFAR-10 Batch 1:  The Validation Cost is 1.09117
# The Validation Accuracy is 0.825
# Epoch 42, CIFAR-10 Batch 1:  The Validation Cost is 1.04137
# The Validation Accuracy is 0.8
# Epoch 43, CIFAR-10 Batch 1:  The Validation Cost is 1.04175
# The Validation Accuracy is 0.8
# Epoch 44, CIFAR-10 Batch 1:  The Validation Cost is 0.968398
# The Validation Accuracy is 0.8
# Epoch 45, CIFAR-10 Batch 1:  The Validation Cost is 0.918975
# The Validation Accuracy is 0.8
# Epoch 46, CIFAR-10 Batch 1:  The Validation Cost is 0.915083
# The Validation Accuracy is 0.825
# Epoch 47, CIFAR-10 Batch 1:  The Validation Cost is 0.898836
# The Validation Accuracy is 0.85
# Epoch 48, CIFAR-10 Batch 1:  The Validation Cost is 0.853885
# The Validation Accuracy is 0.85
# Epoch 49, CIFAR-10 Batch 1:  The Validation Cost is 0.846541
# The Validation Accuracy is 0.85
# Epoch 50, CIFAR-10 Batch 1:  The Validation Cost is 0.809091
# The Validation Accuracy is 0.875
# Epoch 51, CIFAR-10 Batch 1:  The Validation Cost is 0.81393
# The Validation Accuracy is 0.875
# Epoch 52, CIFAR-10 Batch 1:  The Validation Cost is 0.782366
# The Validation Accuracy is 0.85
# Epoch 53, CIFAR-10 Batch 1:  The Validation Cost is 0.782926
# The Validation Accuracy is 0.85
# Epoch 54, CIFAR-10 Batch 1:  The Validation Cost is 0.744707
# The Validation Accuracy is 0.875
# Epoch 55, CIFAR-10 Batch 1:  The Validation Cost is 0.692845
# The Validation Accuracy is 0.925
# Epoch 56, CIFAR-10 Batch 1:  The Validation Cost is 0.721962
# The Validation Accuracy is 0.85
# Epoch 57, CIFAR-10 Batch 1:  The Validation Cost is 0.660521
# The Validation Accuracy is 0.9
# Epoch 58, CIFAR-10 Batch 1:  The Validation Cost is 0.652565
# The Validation Accuracy is 0.925
# Epoch 59, CIFAR-10 Batch 1:  The Validation Cost is 0.666801
# The Validation Accuracy is 0.9
# Epoch 60, CIFAR-10 Batch 1:  The Validation Cost is 0.653936
# The Validation Accuracy is 0.9
# Epoch 61, CIFAR-10 Batch 1:  The Validation Cost is 0.616594
# The Validation Accuracy is 0.925
# Epoch 62, CIFAR-10 Batch 1:  The Validation Cost is 0.580738
# The Validation Accuracy is 0.9
# Epoch 63, CIFAR-10 Batch 1:  The Validation Cost is 0.558027
# The Validation Accuracy is 0.9
# Epoch 64, CIFAR-10 Batch 1:  The Validation Cost is 0.57729
# The Validation Accuracy is 0.95
# Epoch 65, CIFAR-10 Batch 1:  The Validation Cost is 0.549421
# The Validation Accuracy is 0.925
# Epoch 66, CIFAR-10 Batch 1:  The Validation Cost is 0.540431
# The Validation Accuracy is 0.925
# Epoch 67, CIFAR-10 Batch 1:  The Validation Cost is 0.50822
# The Validation Accuracy is 0.925
# Epoch 68, CIFAR-10 Batch 1:  The Validation Cost is 0.50019
# The Validation Accuracy is 0.925
# Epoch 69, CIFAR-10 Batch 1:  The Validation Cost is 0.478941
# The Validation Accuracy is 0.925
# Epoch 70, CIFAR-10 Batch 1:  The Validation Cost is 0.46473
# The Validation Accuracy is 0.95
# Epoch 71, CIFAR-10 Batch 1:  The Validation Cost is 0.436
# The Validation Accuracy is 0.925
# Epoch 72, CIFAR-10 Batch 1:  The Validation Cost is 0.443266
# The Validation Accuracy is 0.925
# Epoch 73, CIFAR-10 Batch 1:  The Validation Cost is 0.395373
# The Validation Accuracy is 0.95
# Epoch 74, CIFAR-10 Batch 1:  The Validation Cost is 0.42733
# The Validation Accuracy is 0.925
# Epoch 75, CIFAR-10 Batch 1:  The Validation Cost is 0.418916
# The Validation Accuracy is 0.95
# Epoch 76, CIFAR-10 Batch 1:  The Validation Cost is 0.411762
# The Validation Accuracy is 0.925
# Epoch 77, CIFAR-10 Batch 1:  The Validation Cost is 0.396232
# The Validation Accuracy is 0.95
# Epoch 78, CIFAR-10 Batch 1:  The Validation Cost is 0.396681
# The Validation Accuracy is 0.9
# Epoch 79, CIFAR-10 Batch 1:  The Validation Cost is 0.385436
# The Validation Accuracy is 0.925
# Epoch 80, CIFAR-10 Batch 1:  The Validation Cost is 0.361578
# The Validation Accuracy is 0.925
# Epoch 81, CIFAR-10 Batch 1:  The Validation Cost is 0.341107
# The Validation Accuracy is 0.95
# Epoch 82, CIFAR-10 Batch 1:  The Validation Cost is 0.325537
# The Validation Accuracy is 0.95
# Epoch 83, CIFAR-10 Batch 1:  The Validation Cost is 0.333669
# The Validation Accuracy is 0.95
# Epoch 84, CIFAR-10 Batch 1:  The Validation Cost is 0.329917
# The Validation Accuracy is 0.95
# Epoch 85, CIFAR-10 Batch 1:  The Validation Cost is 0.293916
# The Validation Accuracy is 0.95
# Epoch 86, CIFAR-10 Batch 1:  The Validation Cost is 0.29555
# The Validation Accuracy is 0.975
# Epoch 87, CIFAR-10 Batch 1:  The Validation Cost is 0.306414
# The Validation Accuracy is 0.95
# Epoch 88, CIFAR-10 Batch 1:  The Validation Cost is 0.307437
# The Validation Accuracy is 0.975
# Epoch 89, CIFAR-10 Batch 1:  The Validation Cost is 0.292682
# The Validation Accuracy is 0.95
# Epoch 90, CIFAR-10 Batch 1:  The Validation Cost is 0.288427
# The Validation Accuracy is 0.975
# Epoch 91, CIFAR-10 Batch 1:  The Validation Cost is 0.281965
# The Validation Accuracy is 0.975
# Epoch 92, CIFAR-10 Batch 1:  The Validation Cost is 0.262845
# The Validation Accuracy is 0.95
# Epoch 93, CIFAR-10 Batch 1:  The Validation Cost is 0.268554
# The Validation Accuracy is 0.975
# Epoch 94, CIFAR-10 Batch 1:  The Validation Cost is 0.243932
# The Validation Accuracy is 0.975
# Epoch 95, CIFAR-10 Batch 1:  The Validation Cost is 0.23195
# The Validation Accuracy is 0.975
# Epoch 96, CIFAR-10 Batch 1:  The Validation Cost is 0.248609
# The Validation Accuracy is 0.975
# Epoch 97, CIFAR-10 Batch 1:  The Validation Cost is 0.220801
# The Validation Accuracy is 0.975
# Epoch 98, CIFAR-10 Batch 1:  The Validation Cost is 0.218664
# The Validation Accuracy is 0.975
# Epoch 99, CIFAR-10 Batch 1:  The Validation Cost is 0.21915
# The Validation Accuracy is 0.95
# Epoch 100, CIFAR-10 Batch 1:  The Validation Cost is 0.236971
# The Validation Accuracy is 0.975

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  The Validation Cost is 2.31451
# The Validation Accuracy is 0.25
# Epoch  1, CIFAR-10 Batch 2:  The Validation Cost is 2.27334
# The Validation Accuracy is 0.2
# Epoch  1, CIFAR-10 Batch 3:  The Validation Cost is 2.27937
# The Validation Accuracy is 0.075
# Epoch  1, CIFAR-10 Batch 4:  The Validation Cost is 2.28135
# The Validation Accuracy is 0.15
# Epoch  1, CIFAR-10 Batch 5:  The Validation Cost is 2.32059
# The Validation Accuracy is 0.1
# Epoch  2, CIFAR-10 Batch 1:  The Validation Cost is 2.29983
# The Validation Accuracy is 0.1
# Epoch  2, CIFAR-10 Batch 2:  The Validation Cost is 2.30247
# The Validation Accuracy is 0.075
# Epoch  2, CIFAR-10 Batch 3:  The Validation Cost is 2.20819
# The Validation Accuracy is 0.25
# Epoch  2, CIFAR-10 Batch 4:  The Validation Cost is 2.20424
# The Validation Accuracy is 0.25
# Epoch  2, CIFAR-10 Batch 5:  The Validation Cost is 2.34799
# The Validation Accuracy is 0.1
# Epoch  3, CIFAR-10 Batch 1:  The Validation Cost is 2.28381
# The Validation Accuracy is 0.075
# Epoch  3, CIFAR-10 Batch 2:  The Validation Cost is 2.28804
# The Validation Accuracy is 0.125
# Epoch  3, CIFAR-10 Batch 3:  The Validation Cost is 2.15339
# The Validation Accuracy is 0.225
# Epoch  3, CIFAR-10 Batch 4:  The Validation Cost is 2.17285
# The Validation Accuracy is 0.15
# Epoch  3, CIFAR-10 Batch 5:  The Validation Cost is 2.36818
# The Validation Accuracy is 0.125
# Epoch  4, CIFAR-10 Batch 1:  The Validation Cost is 2.28569
# The Validation Accuracy is 0.125
# Epoch  4, CIFAR-10 Batch 2:  The Validation Cost is 2.29093
# The Validation Accuracy is 0.2
# Epoch  4, CIFAR-10 Batch 3:  The Validation Cost is 2.13899
# The Validation Accuracy is 0.225
# Epoch  4, CIFAR-10 Batch 4:  The Validation Cost is 2.17222
# The Validation Accuracy is 0.175
# Epoch  4, CIFAR-10 Batch 5:  The Validation Cost is 2.31467
# The Validation Accuracy is 0.1
# Epoch  5, CIFAR-10 Batch 1:  The Validation Cost is 2.31223
# The Validation Accuracy is 0.15
# Epoch  5, CIFAR-10 Batch 2:  The Validation Cost is 2.29024
# The Validation Accuracy is 0.225
# Epoch  5, CIFAR-10 Batch 3:  The Validation Cost is 2.13689
# The Validation Accuracy is 0.175
# Epoch  5, CIFAR-10 Batch 4:  The Validation Cost is 2.14511
# The Validation Accuracy is 0.225
# Epoch  5, CIFAR-10 Batch 5:  The Validation Cost is 2.30627
# The Validation Accuracy is 0.1
# Epoch  6, CIFAR-10 Batch 1:  The Validation Cost is 2.27351
# The Validation Accuracy is 0.1
# Epoch  6, CIFAR-10 Batch 2:  The Validation Cost is 2.28934
# The Validation Accuracy is 0.275
# Epoch  6, CIFAR-10 Batch 3:  The Validation Cost is 2.11697
# The Validation Accuracy is 0.225
# Epoch  6, CIFAR-10 Batch 4:  The Validation Cost is 2.11583
# The Validation Accuracy is 0.25
# Epoch  6, CIFAR-10 Batch 5:  The Validation Cost is 2.29155
# The Validation Accuracy is 0.1
# Epoch  7, CIFAR-10 Batch 1:  The Validation Cost is 2.26716
# The Validation Accuracy is 0.075
# Epoch  7, CIFAR-10 Batch 2:  The Validation Cost is 2.26138
# The Validation Accuracy is 0.275
# Epoch  7, CIFAR-10 Batch 3:  The Validation Cost is 2.13612
# The Validation Accuracy is 0.225
# Epoch  7, CIFAR-10 Batch 4:  The Validation Cost is 2.10261
# The Validation Accuracy is 0.225
# Epoch  7, CIFAR-10 Batch 5:  The Validation Cost is 2.24477
# The Validation Accuracy is 0.1
# Epoch  8, CIFAR-10 Batch 1:  The Validation Cost is 2.25372
# The Validation Accuracy is 0.15
# Epoch  8, CIFAR-10 Batch 2:  The Validation Cost is 2.23
# The Validation Accuracy is 0.25
# Epoch  8, CIFAR-10 Batch 3:  The Validation Cost is 2.1427
# The Validation Accuracy is 0.175
# Epoch  8, CIFAR-10 Batch 4:  The Validation Cost is 2.09188
# The Validation Accuracy is 0.3
# Epoch  8, CIFAR-10 Batch 5:  The Validation Cost is 2.2679
# The Validation Accuracy is 0.125
# Epoch  9, CIFAR-10 Batch 1:  The Validation Cost is 2.24555
# The Validation Accuracy is 0.175
# Epoch  9, CIFAR-10 Batch 2:  The Validation Cost is 2.25397
# The Validation Accuracy is 0.225
# Epoch  9, CIFAR-10 Batch 3:  The Validation Cost is 2.13157
# The Validation Accuracy is 0.175
# Epoch  9, CIFAR-10 Batch 4:  The Validation Cost is 2.07391
# The Validation Accuracy is 0.225
# Epoch  9, CIFAR-10 Batch 5:  The Validation Cost is 2.23726
# The Validation Accuracy is 0.125
# Epoch 10, CIFAR-10 Batch 1:  The Validation Cost is 2.23891
# The Validation Accuracy is 0.15
# Epoch 10, CIFAR-10 Batch 2:  The Validation Cost is 2.20543
# The Validation Accuracy is 0.225
# Epoch 10, CIFAR-10 Batch 3:  The Validation Cost is 2.14303
# The Validation Accuracy is 0.2
# Epoch 10, CIFAR-10 Batch 4:  The Validation Cost is 2.05659
# The Validation Accuracy is 0.225
# Epoch 10, CIFAR-10 Batch 5:  The Validation Cost is 2.23891
# The Validation Accuracy is 0.1
# Epoch 11, CIFAR-10 Batch 1:  The Validation Cost is 2.2101
# The Validation Accuracy is 0.2
# Epoch 11, CIFAR-10 Batch 2:  The Validation Cost is 2.22411
# The Validation Accuracy is 0.3
# Epoch 11, CIFAR-10 Batch 3:  The Validation Cost is 2.0947
# The Validation Accuracy is 0.275
# Epoch 11, CIFAR-10 Batch 4:  The Validation Cost is 2.04684
# The Validation Accuracy is 0.2
# Epoch 11, CIFAR-10 Batch 5:  The Validation Cost is 2.23355
# The Validation Accuracy is 0.2
# Epoch 12, CIFAR-10 Batch 1:  The Validation Cost is 2.20647
# The Validation Accuracy is 0.15
# Epoch 12, CIFAR-10 Batch 2:  The Validation Cost is 2.18564
# The Validation Accuracy is 0.3
# Epoch 12, CIFAR-10 Batch 3:  The Validation Cost is 2.09988
# The Validation Accuracy is 0.2
# Epoch 12, CIFAR-10 Batch 4:  The Validation Cost is 2.05006
# The Validation Accuracy is 0.2
# Epoch 12, CIFAR-10 Batch 5:  The Validation Cost is 2.25329
# The Validation Accuracy is 0.175
# Epoch 13, CIFAR-10 Batch 1:  The Validation Cost is 2.22094
# The Validation Accuracy is 0.125
# Epoch 13, CIFAR-10 Batch 2:  The Validation Cost is 2.17078
# The Validation Accuracy is 0.275
# Epoch 13, CIFAR-10 Batch 3:  The Validation Cost is 2.05406
# The Validation Accuracy is 0.275
# Epoch 13, CIFAR-10 Batch 4:  The Validation Cost is 2.07138
# The Validation Accuracy is 0.2
# Epoch 13, CIFAR-10 Batch 5:  The Validation Cost is 2.25688
# The Validation Accuracy is 0.125
# Epoch 14, CIFAR-10 Batch 1:  The Validation Cost is 2.17722
# The Validation Accuracy is 0.175
# Epoch 14, CIFAR-10 Batch 2:  The Validation Cost is 2.17878
# The Validation Accuracy is 0.3
# Epoch 14, CIFAR-10 Batch 3:  The Validation Cost is 2.07903
# The Validation Accuracy is 0.225
# Epoch 14, CIFAR-10 Batch 4:  The Validation Cost is 2.05929
# The Validation Accuracy is 0.25
# Epoch 14, CIFAR-10 Batch 5:  The Validation Cost is 2.25767
# The Validation Accuracy is 0.075
# Epoch 15, CIFAR-10 Batch 1:  The Validation Cost is 2.15162
# The Validation Accuracy is 0.15
# Epoch 15, CIFAR-10 Batch 2:  The Validation Cost is 2.1303
# The Validation Accuracy is 0.35
# Epoch 15, CIFAR-10 Batch 3:  The Validation Cost is 2.00981
# The Validation Accuracy is 0.325
# Epoch 15, CIFAR-10 Batch 4:  The Validation Cost is 2.03556
# The Validation Accuracy is 0.225
# Epoch 15, CIFAR-10 Batch 5:  The Validation Cost is 2.27661
# The Validation Accuracy is 0.1
# Epoch 16, CIFAR-10 Batch 1:  The Validation Cost is 2.15201
# The Validation Accuracy is 0.125
# Epoch 16, CIFAR-10 Batch 2:  The Validation Cost is 2.10333
# The Validation Accuracy is 0.375
# Epoch 16, CIFAR-10 Batch 3:  The Validation Cost is 2.00264
# The Validation Accuracy is 0.325
# Epoch 16, CIFAR-10 Batch 4:  The Validation Cost is 2.00461
# The Validation Accuracy is 0.25
# Epoch 16, CIFAR-10 Batch 5:  The Validation Cost is 2.21975
# The Validation Accuracy is 0.175
# Epoch 17, CIFAR-10 Batch 1:  The Validation Cost is 2.13835
# The Validation Accuracy is 0.15
# Epoch 17, CIFAR-10 Batch 2:  The Validation Cost is 2.08109
# The Validation Accuracy is 0.375
# Epoch 17, CIFAR-10 Batch 3:  The Validation Cost is 2.01099
# The Validation Accuracy is 0.325
# Epoch 17, CIFAR-10 Batch 4:  The Validation Cost is 2.01029
# The Validation Accuracy is 0.275
# Epoch 17, CIFAR-10 Batch 5:  The Validation Cost is 2.19425
# The Validation Accuracy is 0.125
# Epoch 18, CIFAR-10 Batch 1:  The Validation Cost is 2.12077
# The Validation Accuracy is 0.15
# Epoch 18, CIFAR-10 Batch 2:  The Validation Cost is 2.07635
# The Validation Accuracy is 0.375
# Epoch 18, CIFAR-10 Batch 3:  The Validation Cost is 1.98858
# The Validation Accuracy is 0.325
# Epoch 18, CIFAR-10 Batch 4:  The Validation Cost is 1.98484
# The Validation Accuracy is 0.225
# Epoch 18, CIFAR-10 Batch 5:  The Validation Cost is 2.16622
# The Validation Accuracy is 0.2
# Epoch 19, CIFAR-10 Batch 1:  The Validation Cost is 2.09166
# The Validation Accuracy is 0.175
# Epoch 19, CIFAR-10 Batch 2:  The Validation Cost is 2.05677
# The Validation Accuracy is 0.35
# Epoch 19, CIFAR-10 Batch 3:  The Validation Cost is 1.95447
# The Validation Accuracy is 0.275
# Epoch 19, CIFAR-10 Batch 4:  The Validation Cost is 1.95725
# The Validation Accuracy is 0.275
# Epoch 19, CIFAR-10 Batch 5:  The Validation Cost is 2.17847
# The Validation Accuracy is 0.175
# Epoch 20, CIFAR-10 Batch 1:  The Validation Cost is 2.06072
# The Validation Accuracy is 0.2
# Epoch 20, CIFAR-10 Batch 2:  The Validation Cost is 2.05399
# The Validation Accuracy is 0.35
# Epoch 20, CIFAR-10 Batch 3:  The Validation Cost is 1.95686
# The Validation Accuracy is 0.375
# Epoch 20, CIFAR-10 Batch 4:  The Validation Cost is 1.95579
# The Validation Accuracy is 0.3
# Epoch 20, CIFAR-10 Batch 5:  The Validation Cost is 2.15647
# The Validation Accuracy is 0.2
# Epoch 21, CIFAR-10 Batch 1:  The Validation Cost is 2.03147
# The Validation Accuracy is 0.2
# Epoch 21, CIFAR-10 Batch 2:  The Validation Cost is 2.02061
# The Validation Accuracy is 0.325
# Epoch 21, CIFAR-10 Batch 3:  The Validation Cost is 1.97915
# The Validation Accuracy is 0.325
# Epoch 21, CIFAR-10 Batch 4:  The Validation Cost is 1.91593
# The Validation Accuracy is 0.325
# Epoch 21, CIFAR-10 Batch 5:  The Validation Cost is 2.15024
# The Validation Accuracy is 0.275
# Epoch 22, CIFAR-10 Batch 1:  The Validation Cost is 1.99606
# The Validation Accuracy is 0.175
# Epoch 22, CIFAR-10 Batch 2:  The Validation Cost is 1.99878
# The Validation Accuracy is 0.325
# Epoch 22, CIFAR-10 Batch 3:  The Validation Cost is 1.93542
# The Validation Accuracy is 0.35
# Epoch 22, CIFAR-10 Batch 4:  The Validation Cost is 1.92297
# The Validation Accuracy is 0.325
# Epoch 22, CIFAR-10 Batch 5:  The Validation Cost is 2.14671
# The Validation Accuracy is 0.2
# Epoch 23, CIFAR-10 Batch 1:  The Validation Cost is 1.98439
# The Validation Accuracy is 0.225
# Epoch 23, CIFAR-10 Batch 2:  The Validation Cost is 1.93799
# The Validation Accuracy is 0.4
# Epoch 23, CIFAR-10 Batch 3:  The Validation Cost is 1.93517
# The Validation Accuracy is 0.4
# Epoch 23, CIFAR-10 Batch 4:  The Validation Cost is 1.87987
# The Validation Accuracy is 0.325
# Epoch 23, CIFAR-10 Batch 5:  The Validation Cost is 2.1086
# The Validation Accuracy is 0.25
# Epoch 24, CIFAR-10 Batch 1:  The Validation Cost is 1.98653
# The Validation Accuracy is 0.225
# Epoch 24, CIFAR-10 Batch 2:  The Validation Cost is 1.91685
# The Validation Accuracy is 0.375
# Epoch 24, CIFAR-10 Batch 3:  The Validation Cost is 1.90589
# The Validation Accuracy is 0.375
# Epoch 24, CIFAR-10 Batch 4:  The Validation Cost is 1.85773
# The Validation Accuracy is 0.375
# Epoch 24, CIFAR-10 Batch 5:  The Validation Cost is 2.11972
# The Validation Accuracy is 0.2
# Epoch 25, CIFAR-10 Batch 1:  The Validation Cost is 1.97964
# The Validation Accuracy is 0.25
# Epoch 25, CIFAR-10 Batch 2:  The Validation Cost is 1.94234
# The Validation Accuracy is 0.375
# Epoch 25, CIFAR-10 Batch 3:  The Validation Cost is 1.87898
# The Validation Accuracy is 0.4
# Epoch 25, CIFAR-10 Batch 4:  The Validation Cost is 1.83108
# The Validation Accuracy is 0.375
# Epoch 25, CIFAR-10 Batch 5:  The Validation Cost is 2.09336
# The Validation Accuracy is 0.2
# Epoch 26, CIFAR-10 Batch 1:  The Validation Cost is 1.96777
# The Validation Accuracy is 0.2
# Epoch 26, CIFAR-10 Batch 2:  The Validation Cost is 1.93756
# The Validation Accuracy is 0.325
# Epoch 26, CIFAR-10 Batch 3:  The Validation Cost is 1.89246
# The Validation Accuracy is 0.375
# Epoch 26, CIFAR-10 Batch 4:  The Validation Cost is 1.835
# The Validation Accuracy is 0.375
# Epoch 26, CIFAR-10 Batch 5:  The Validation Cost is 2.08828
# The Validation Accuracy is 0.2
# Epoch 27, CIFAR-10 Batch 1:  The Validation Cost is 1.93699
# The Validation Accuracy is 0.2
# Epoch 27, CIFAR-10 Batch 2:  The Validation Cost is 1.8648
# The Validation Accuracy is 0.425
# Epoch 27, CIFAR-10 Batch 3:  The Validation Cost is 1.86118
# The Validation Accuracy is 0.375
# Epoch 27, CIFAR-10 Batch 4:  The Validation Cost is 1.87117
# The Validation Accuracy is 0.375
# Epoch 27, CIFAR-10 Batch 5:  The Validation Cost is 2.08378
# The Validation Accuracy is 0.2
# Epoch 28, CIFAR-10 Batch 1:  The Validation Cost is 1.90092
# The Validation Accuracy is 0.2
# Epoch 28, CIFAR-10 Batch 2:  The Validation Cost is 1.82254
# The Validation Accuracy is 0.375
# Epoch 28, CIFAR-10 Batch 3:  The Validation Cost is 1.84442
# The Validation Accuracy is 0.425
# Epoch 28, CIFAR-10 Batch 4:  The Validation Cost is 1.83636
# The Validation Accuracy is 0.4
# Epoch 28, CIFAR-10 Batch 5:  The Validation Cost is 2.03103
# The Validation Accuracy is 0.25
# Epoch 29, CIFAR-10 Batch 1:  The Validation Cost is 1.86957
# The Validation Accuracy is 0.3
# Epoch 29, CIFAR-10 Batch 2:  The Validation Cost is 1.80595
# The Validation Accuracy is 0.375
# Epoch 29, CIFAR-10 Batch 3:  The Validation Cost is 1.83154
# The Validation Accuracy is 0.475
# Epoch 29, CIFAR-10 Batch 4:  The Validation Cost is 1.80759
# The Validation Accuracy is 0.375
# Epoch 29, CIFAR-10 Batch 5:  The Validation Cost is 2.04546
# The Validation Accuracy is 0.2
# Epoch 30, CIFAR-10 Batch 1:  The Validation Cost is 1.8793
# The Validation Accuracy is 0.225
# Epoch 30, CIFAR-10 Batch 2:  The Validation Cost is 1.80593
# The Validation Accuracy is 0.45
# Epoch 30, CIFAR-10 Batch 3:  The Validation Cost is 1.83858
# The Validation Accuracy is 0.425
# Epoch 30, CIFAR-10 Batch 4:  The Validation Cost is 1.81916
# The Validation Accuracy is 0.425
# Epoch 30, CIFAR-10 Batch 5:  The Validation Cost is 2.03211
# The Validation Accuracy is 0.2
# Epoch 31, CIFAR-10 Batch 1:  The Validation Cost is 1.87934
# The Validation Accuracy is 0.25
# Epoch 31, CIFAR-10 Batch 2:  The Validation Cost is 1.78783
# The Validation Accuracy is 0.45
# Epoch 31, CIFAR-10 Batch 3:  The Validation Cost is 1.80958
# The Validation Accuracy is 0.45
# Epoch 31, CIFAR-10 Batch 4:  The Validation Cost is 1.81008
# The Validation Accuracy is 0.4
# Epoch 31, CIFAR-10 Batch 5:  The Validation Cost is 2.02858
# The Validation Accuracy is 0.225
# Epoch 32, CIFAR-10 Batch 1:  The Validation Cost is 1.83085
# The Validation Accuracy is 0.275
# Epoch 32, CIFAR-10 Batch 2:  The Validation Cost is 1.77329
# The Validation Accuracy is 0.4
# Epoch 32, CIFAR-10 Batch 3:  The Validation Cost is 1.79287
# The Validation Accuracy is 0.45
# Epoch 32, CIFAR-10 Batch 4:  The Validation Cost is 1.78265
# The Validation Accuracy is 0.45
# Epoch 32, CIFAR-10 Batch 5:  The Validation Cost is 2.01786
# The Validation Accuracy is 0.275
# Epoch 33, CIFAR-10 Batch 1:  The Validation Cost is 1.79333
# The Validation Accuracy is 0.275
# Epoch 33, CIFAR-10 Batch 2:  The Validation Cost is 1.72307
# The Validation Accuracy is 0.4
# Epoch 33, CIFAR-10 Batch 3:  The Validation Cost is 1.8522
# The Validation Accuracy is 0.4
# Epoch 33, CIFAR-10 Batch 4:  The Validation Cost is 1.74806
# The Validation Accuracy is 0.525
# Epoch 33, CIFAR-10 Batch 5:  The Validation Cost is 2.03355
# The Validation Accuracy is 0.225
# Epoch 34, CIFAR-10 Batch 1:  The Validation Cost is 1.80921
# The Validation Accuracy is 0.325
# Epoch 34, CIFAR-10 Batch 2:  The Validation Cost is 1.72963
# The Validation Accuracy is 0.425
# Epoch 34, CIFAR-10 Batch 3:  The Validation Cost is 1.77743
# The Validation Accuracy is 0.375
# Epoch 34, CIFAR-10 Batch 4:  The Validation Cost is 1.74865
# The Validation Accuracy is 0.425
# Epoch 34, CIFAR-10 Batch 5:  The Validation Cost is 1.98068
# The Validation Accuracy is 0.2
# Epoch 35, CIFAR-10 Batch 1:  The Validation Cost is 1.81024
# The Validation Accuracy is 0.275
# Epoch 35, CIFAR-10 Batch 2:  The Validation Cost is 1.73348
# The Validation Accuracy is 0.4
# Epoch 35, CIFAR-10 Batch 3:  The Validation Cost is 1.79262
# The Validation Accuracy is 0.4
# Epoch 35, CIFAR-10 Batch 4:  The Validation Cost is 1.75766
# The Validation Accuracy is 0.475
# Epoch 35, CIFAR-10 Batch 5:  The Validation Cost is 1.95238
# The Validation Accuracy is 0.3
# Epoch 36, CIFAR-10 Batch 1:  The Validation Cost is 1.77136
# The Validation Accuracy is 0.325
# Epoch 36, CIFAR-10 Batch 2:  The Validation Cost is 1.67934
# The Validation Accuracy is 0.4
# Epoch 36, CIFAR-10 Batch 3:  The Validation Cost is 1.75985
# The Validation Accuracy is 0.425
# Epoch 36, CIFAR-10 Batch 4:  The Validation Cost is 1.73182
# The Validation Accuracy is 0.45
# Epoch 36, CIFAR-10 Batch 5:  The Validation Cost is 1.97442
# The Validation Accuracy is 0.2
# Epoch 37, CIFAR-10 Batch 1:  The Validation Cost is 1.79092
# The Validation Accuracy is 0.35
# Epoch 37, CIFAR-10 Batch 2:  The Validation Cost is 1.70018
# The Validation Accuracy is 0.425
# Epoch 37, CIFAR-10 Batch 3:  The Validation Cost is 1.74291
# The Validation Accuracy is 0.45
# Epoch 37, CIFAR-10 Batch 4:  The Validation Cost is 1.76545
# The Validation Accuracy is 0.45
# Epoch 37, CIFAR-10 Batch 5:  The Validation Cost is 1.94613
# The Validation Accuracy is 0.225
# Epoch 38, CIFAR-10 Batch 1:  The Validation Cost is 1.75117
# The Validation Accuracy is 0.35
# Epoch 38, CIFAR-10 Batch 2:  The Validation Cost is 1.67598
# The Validation Accuracy is 0.45
# Epoch 38, CIFAR-10 Batch 3:  The Validation Cost is 1.72349
# The Validation Accuracy is 0.4
# Epoch 38, CIFAR-10 Batch 4:  The Validation Cost is 1.71651
# The Validation Accuracy is 0.525
# Epoch 38, CIFAR-10 Batch 5:  The Validation Cost is 1.95056
# The Validation Accuracy is 0.225
# Epoch 39, CIFAR-10 Batch 1:  The Validation Cost is 1.74703
# The Validation Accuracy is 0.325
# Epoch 39, CIFAR-10 Batch 2:  The Validation Cost is 1.6749
# The Validation Accuracy is 0.45
# Epoch 39, CIFAR-10 Batch 3:  The Validation Cost is 1.72344
# The Validation Accuracy is 0.425
# Epoch 39, CIFAR-10 Batch 4:  The Validation Cost is 1.70678
# The Validation Accuracy is 0.525
# Epoch 39, CIFAR-10 Batch 5:  The Validation Cost is 1.96552
# The Validation Accuracy is 0.2
# Epoch 40, CIFAR-10 Batch 1:  The Validation Cost is 1.72344
# The Validation Accuracy is 0.35
# Epoch 40, CIFAR-10 Batch 2:  The Validation Cost is 1.63316
# The Validation Accuracy is 0.425
# Epoch 40, CIFAR-10 Batch 3:  The Validation Cost is 1.70492
# The Validation Accuracy is 0.425
# Epoch 40, CIFAR-10 Batch 4:  The Validation Cost is 1.69672
# The Validation Accuracy is 0.475
# Epoch 40, CIFAR-10 Batch 5:  The Validation Cost is 1.9332
# The Validation Accuracy is 0.275
# Epoch 41, CIFAR-10 Batch 1:  The Validation Cost is 1.71074
# The Validation Accuracy is 0.325
# Epoch 41, CIFAR-10 Batch 2:  The Validation Cost is 1.64566
# The Validation Accuracy is 0.425
# Epoch 41, CIFAR-10 Batch 3:  The Validation Cost is 1.70341
# The Validation Accuracy is 0.375
# Epoch 41, CIFAR-10 Batch 4:  The Validation Cost is 1.69443
# The Validation Accuracy is 0.45
# Epoch 41, CIFAR-10 Batch 5:  The Validation Cost is 1.94367
# The Validation Accuracy is 0.25
# Epoch 42, CIFAR-10 Batch 1:  The Validation Cost is 1.69305
# The Validation Accuracy is 0.325
# Epoch 42, CIFAR-10 Batch 2:  The Validation Cost is 1.60485
# The Validation Accuracy is 0.45
# Epoch 42, CIFAR-10 Batch 3:  The Validation Cost is 1.68373
# The Validation Accuracy is 0.475
# Epoch 42, CIFAR-10 Batch 4:  The Validation Cost is 1.69271
# The Validation Accuracy is 0.5
# Epoch 42, CIFAR-10 Batch 5:  The Validation Cost is 1.88817
# The Validation Accuracy is 0.275
# Epoch 43, CIFAR-10 Batch 1:  The Validation Cost is 1.66076
# The Validation Accuracy is 0.4
# Epoch 43, CIFAR-10 Batch 2:  The Validation Cost is 1.59573
# The Validation Accuracy is 0.425
# Epoch 43, CIFAR-10 Batch 3:  The Validation Cost is 1.65503
# The Validation Accuracy is 0.5
# Epoch 43, CIFAR-10 Batch 4:  The Validation Cost is 1.68431
# The Validation Accuracy is 0.5
# Epoch 43, CIFAR-10 Batch 5:  The Validation Cost is 1.85321
# The Validation Accuracy is 0.3
# Epoch 44, CIFAR-10 Batch 1:  The Validation Cost is 1.67178
# The Validation Accuracy is 0.35
# Epoch 44, CIFAR-10 Batch 2:  The Validation Cost is 1.61654
# The Validation Accuracy is 0.45
# Epoch 44, CIFAR-10 Batch 3:  The Validation Cost is 1.64798
# The Validation Accuracy is 0.5
# Epoch 44, CIFAR-10 Batch 4:  The Validation Cost is 1.66649
# The Validation Accuracy is 0.5
# Epoch 44, CIFAR-10 Batch 5:  The Validation Cost is 1.86839
# The Validation Accuracy is 0.35
# Epoch 45, CIFAR-10 Batch 1:  The Validation Cost is 1.6645
# The Validation Accuracy is 0.425
# Epoch 45, CIFAR-10 Batch 2:  The Validation Cost is 1.55996
# The Validation Accuracy is 0.45
# Epoch 45, CIFAR-10 Batch 3:  The Validation Cost is 1.63239
# The Validation Accuracy is 0.45
# Epoch 45, CIFAR-10 Batch 4:  The Validation Cost is 1.67369
# The Validation Accuracy is 0.475
# Epoch 45, CIFAR-10 Batch 5:  The Validation Cost is 1.85212
# The Validation Accuracy is 0.35
# Epoch 46, CIFAR-10 Batch 1:  The Validation Cost is 1.61675
# The Validation Accuracy is 0.4
# Epoch 46, CIFAR-10 Batch 2:  The Validation Cost is 1.58167
# The Validation Accuracy is 0.45
# Epoch 46, CIFAR-10 Batch 3:  The Validation Cost is 1.59768
# The Validation Accuracy is 0.5
# Epoch 46, CIFAR-10 Batch 4:  The Validation Cost is 1.63681
# The Validation Accuracy is 0.525
# Epoch 46, CIFAR-10 Batch 5:  The Validation Cost is 1.86203
# The Validation Accuracy is 0.325
# Epoch 47, CIFAR-10 Batch 1:  The Validation Cost is 1.63541
# The Validation Accuracy is 0.425
# Epoch 47, CIFAR-10 Batch 2:  The Validation Cost is 1.59107
# The Validation Accuracy is 0.425
# Epoch 47, CIFAR-10 Batch 3:  The Validation Cost is 1.59485
# The Validation Accuracy is 0.475
# Epoch 47, CIFAR-10 Batch 4:  The Validation Cost is 1.62028
# The Validation Accuracy is 0.5
# Epoch 47, CIFAR-10 Batch 5:  The Validation Cost is 1.85222
# The Validation Accuracy is 0.3
# Epoch 48, CIFAR-10 Batch 1:  The Validation Cost is 1.64799
# The Validation Accuracy is 0.375
# Epoch 48, CIFAR-10 Batch 2:  The Validation Cost is 1.5543
# The Validation Accuracy is 0.45
# Epoch 48, CIFAR-10 Batch 3:  The Validation Cost is 1.56064
# The Validation Accuracy is 0.525
# Epoch 48, CIFAR-10 Batch 4:  The Validation Cost is 1.60863
# The Validation Accuracy is 0.525
# Epoch 48, CIFAR-10 Batch 5:  The Validation Cost is 1.83794
# The Validation Accuracy is 0.35
# Epoch 49, CIFAR-10 Batch 1:  The Validation Cost is 1.63903
# The Validation Accuracy is 0.375
# Epoch 49, CIFAR-10 Batch 2:  The Validation Cost is 1.54231
# The Validation Accuracy is 0.45
# Epoch 49, CIFAR-10 Batch 3:  The Validation Cost is 1.58193
# The Validation Accuracy is 0.575
# Epoch 49, CIFAR-10 Batch 4:  The Validation Cost is 1.64035
# The Validation Accuracy is 0.45
# Epoch 49, CIFAR-10 Batch 5:  The Validation Cost is 1.85654
# The Validation Accuracy is 0.325
# Epoch 50, CIFAR-10 Batch 1:  The Validation Cost is 1.57377
# The Validation Accuracy is 0.45
# Epoch 50, CIFAR-10 Batch 2:  The Validation Cost is 1.53768
# The Validation Accuracy is 0.5
# Epoch 50, CIFAR-10 Batch 3:  The Validation Cost is 1.56745
# The Validation Accuracy is 0.5
# Epoch 50, CIFAR-10 Batch 4:  The Validation Cost is 1.64191
# The Validation Accuracy is 0.55
# Epoch 50, CIFAR-10 Batch 5:  The Validation Cost is 1.84642
# The Validation Accuracy is 0.325
# Epoch 51, CIFAR-10 Batch 1:  The Validation Cost is 1.59182
# The Validation Accuracy is 0.425
# Epoch 51, CIFAR-10 Batch 2:  The Validation Cost is 1.51706
# The Validation Accuracy is 0.525
# Epoch 51, CIFAR-10 Batch 3:  The Validation Cost is 1.53535
# The Validation Accuracy is 0.475
# Epoch 51, CIFAR-10 Batch 4:  The Validation Cost is 1.59811
# The Validation Accuracy is 0.55
# Epoch 51, CIFAR-10 Batch 5:  The Validation Cost is 1.84929
# The Validation Accuracy is 0.325
# Epoch 52, CIFAR-10 Batch 1:  The Validation Cost is 1.56079
# The Validation Accuracy is 0.4
# Epoch 52, CIFAR-10 Batch 2:  The Validation Cost is 1.54282
# The Validation Accuracy is 0.475
# Epoch 52, CIFAR-10 Batch 3:  The Validation Cost is 1.53372
# The Validation Accuracy is 0.6
# Epoch 52, CIFAR-10 Batch 4:  The Validation Cost is 1.59738
# The Validation Accuracy is 0.525
# Epoch 52, CIFAR-10 Batch 5:  The Validation Cost is 1.84044
# The Validation Accuracy is 0.35
# Epoch 53, CIFAR-10 Batch 1:  The Validation Cost is 1.61172
# The Validation Accuracy is 0.4
# Epoch 53, CIFAR-10 Batch 2:  The Validation Cost is 1.51883
# The Validation Accuracy is 0.425
# Epoch 53, CIFAR-10 Batch 3:  The Validation Cost is 1.52072
# The Validation Accuracy is 0.55
# Epoch 53, CIFAR-10 Batch 4:  The Validation Cost is 1.57026
# The Validation Accuracy is 0.5
# Epoch 53, CIFAR-10 Batch 5:  The Validation Cost is 1.80463
# The Validation Accuracy is 0.35
# Epoch 54, CIFAR-10 Batch 1:  The Validation Cost is 1.53207
# The Validation Accuracy is 0.45
# Epoch 54, CIFAR-10 Batch 2:  The Validation Cost is 1.52012
# The Validation Accuracy is 0.375
# Epoch 54, CIFAR-10 Batch 3:  The Validation Cost is 1.52917
# The Validation Accuracy is 0.55
# Epoch 54, CIFAR-10 Batch 4:  The Validation Cost is 1.58945
# The Validation Accuracy is 0.525
# Epoch 54, CIFAR-10 Batch 5:  The Validation Cost is 1.79842
# The Validation Accuracy is 0.325
# Epoch 55, CIFAR-10 Batch 1:  The Validation Cost is 1.53428
# The Validation Accuracy is 0.4
# Epoch 55, CIFAR-10 Batch 2:  The Validation Cost is 1.51886
# The Validation Accuracy is 0.45
# Epoch 55, CIFAR-10 Batch 3:  The Validation Cost is 1.5342
# The Validation Accuracy is 0.55
# Epoch 55, CIFAR-10 Batch 4:  The Validation Cost is 1.55637
# The Validation Accuracy is 0.525
# Epoch 55, CIFAR-10 Batch 5:  The Validation Cost is 1.82153
# The Validation Accuracy is 0.375
# Epoch 56, CIFAR-10 Batch 1:  The Validation Cost is 1.54591
# The Validation Accuracy is 0.425
# Epoch 56, CIFAR-10 Batch 2:  The Validation Cost is 1.49233
# The Validation Accuracy is 0.525
# Epoch 56, CIFAR-10 Batch 3:  The Validation Cost is 1.50244
# The Validation Accuracy is 0.55
# Epoch 56, CIFAR-10 Batch 4:  The Validation Cost is 1.55173
# The Validation Accuracy is 0.525
# Epoch 56, CIFAR-10 Batch 5:  The Validation Cost is 1.77489
# The Validation Accuracy is 0.325
# Epoch 57, CIFAR-10 Batch 1:  The Validation Cost is 1.54155
# The Validation Accuracy is 0.45
# Epoch 57, CIFAR-10 Batch 2:  The Validation Cost is 1.52356
# The Validation Accuracy is 0.4
# Epoch 57, CIFAR-10 Batch 3:  The Validation Cost is 1.51752
# The Validation Accuracy is 0.525
# Epoch 57, CIFAR-10 Batch 4:  The Validation Cost is 1.53491
# The Validation Accuracy is 0.5
# Epoch 57, CIFAR-10 Batch 5:  The Validation Cost is 1.81491
# The Validation Accuracy is 0.35
# Epoch 58, CIFAR-10 Batch 1:  The Validation Cost is 1.51151
# The Validation Accuracy is 0.45
# Epoch 58, CIFAR-10 Batch 2:  The Validation Cost is 1.50944
# The Validation Accuracy is 0.4
# Epoch 58, CIFAR-10 Batch 3:  The Validation Cost is 1.50345
# The Validation Accuracy is 0.575
# Epoch 58, CIFAR-10 Batch 4:  The Validation Cost is 1.5281
# The Validation Accuracy is 0.5
# Epoch 58, CIFAR-10 Batch 5:  The Validation Cost is 1.77861
# The Validation Accuracy is 0.35
# Epoch 59, CIFAR-10 Batch 1:  The Validation Cost is 1.50097
# The Validation Accuracy is 0.45
# Epoch 59, CIFAR-10 Batch 2:  The Validation Cost is 1.46118
# The Validation Accuracy is 0.5
# Epoch 59, CIFAR-10 Batch 3:  The Validation Cost is 1.52387
# The Validation Accuracy is 0.55
# Epoch 59, CIFAR-10 Batch 4:  The Validation Cost is 1.51036
# The Validation Accuracy is 0.55
# Epoch 59, CIFAR-10 Batch 5:  The Validation Cost is 1.76341
# The Validation Accuracy is 0.375
# Epoch 60, CIFAR-10 Batch 1:  The Validation Cost is 1.48764
# The Validation Accuracy is 0.45
# Epoch 60, CIFAR-10 Batch 2:  The Validation Cost is 1.46702
# The Validation Accuracy is 0.525
# Epoch 60, CIFAR-10 Batch 3:  The Validation Cost is 1.45016
# The Validation Accuracy is 0.65
# Epoch 60, CIFAR-10 Batch 4:  The Validation Cost is 1.49189
# The Validation Accuracy is 0.55
# Epoch 60, CIFAR-10 Batch 5:  The Validation Cost is 1.75085
# The Validation Accuracy is 0.325
# Epoch 61, CIFAR-10 Batch 1:  The Validation Cost is 1.49802
# The Validation Accuracy is 0.375
# Epoch 61, CIFAR-10 Batch 2:  The Validation Cost is 1.47891
# The Validation Accuracy is 0.45
# Epoch 61, CIFAR-10 Batch 3:  The Validation Cost is 1.444
# The Validation Accuracy is 0.65
# Epoch 61, CIFAR-10 Batch 4:  The Validation Cost is 1.52859
# The Validation Accuracy is 0.475
# Epoch 61, CIFAR-10 Batch 5:  The Validation Cost is 1.77017
# The Validation Accuracy is 0.35
# Epoch 62, CIFAR-10 Batch 1:  The Validation Cost is 1.49075
# The Validation Accuracy is 0.425
# Epoch 62, CIFAR-10 Batch 2:  The Validation Cost is 1.48707
# The Validation Accuracy is 0.475
# Epoch 62, CIFAR-10 Batch 3:  The Validation Cost is 1.4587
# The Validation Accuracy is 0.625
# Epoch 62, CIFAR-10 Batch 4:  The Validation Cost is 1.52949
# The Validation Accuracy is 0.475
# Epoch 62, CIFAR-10 Batch 5:  The Validation Cost is 1.72063
# The Validation Accuracy is 0.4
# Epoch 63, CIFAR-10 Batch 1:  The Validation Cost is 1.44855
# The Validation Accuracy is 0.45
# Epoch 63, CIFAR-10 Batch 2:  The Validation Cost is 1.47834
# The Validation Accuracy is 0.5
# Epoch 63, CIFAR-10 Batch 3:  The Validation Cost is 1.47324
# The Validation Accuracy is 0.6
# Epoch 63, CIFAR-10 Batch 4:  The Validation Cost is 1.51625
# The Validation Accuracy is 0.5
# Epoch 63, CIFAR-10 Batch 5:  The Validation Cost is 1.74436
# The Validation Accuracy is 0.4
# Epoch 64, CIFAR-10 Batch 1:  The Validation Cost is 1.45404
# The Validation Accuracy is 0.475
# Epoch 64, CIFAR-10 Batch 2:  The Validation Cost is 1.43872
# The Validation Accuracy is 0.5
# Epoch 64, CIFAR-10 Batch 3:  The Validation Cost is 1.45073
# The Validation Accuracy is 0.575
# Epoch 64, CIFAR-10 Batch 4:  The Validation Cost is 1.48856
# The Validation Accuracy is 0.5
# Epoch 64, CIFAR-10 Batch 5:  The Validation Cost is 1.70832
# The Validation Accuracy is 0.35
# Epoch 65, CIFAR-10 Batch 1:  The Validation Cost is 1.44527
# The Validation Accuracy is 0.45
# Epoch 65, CIFAR-10 Batch 2:  The Validation Cost is 1.43707
# The Validation Accuracy is 0.425
# Epoch 65, CIFAR-10 Batch 3:  The Validation Cost is 1.45665
# The Validation Accuracy is 0.625
# Epoch 65, CIFAR-10 Batch 4:  The Validation Cost is 1.46766
# The Validation Accuracy is 0.55
# Epoch 65, CIFAR-10 Batch 5:  The Validation Cost is 1.72365
# The Validation Accuracy is 0.375
# Epoch 66, CIFAR-10 Batch 1:  The Validation Cost is 1.42534
# The Validation Accuracy is 0.45
# Epoch 66, CIFAR-10 Batch 2:  The Validation Cost is 1.44685
# The Validation Accuracy is 0.5
# Epoch 66, CIFAR-10 Batch 3:  The Validation Cost is 1.47098
# The Validation Accuracy is 0.625
# Epoch 66, CIFAR-10 Batch 4:  The Validation Cost is 1.48554
# The Validation Accuracy is 0.5
# Epoch 66, CIFAR-10 Batch 5:  The Validation Cost is 1.72094
# The Validation Accuracy is 0.375
# Epoch 67, CIFAR-10 Batch 1:  The Validation Cost is 1.47798
# The Validation Accuracy is 0.425
# Epoch 67, CIFAR-10 Batch 2:  The Validation Cost is 1.41158
# The Validation Accuracy is 0.475
# Epoch 67, CIFAR-10 Batch 3:  The Validation Cost is 1.42316
# The Validation Accuracy is 0.675
# Epoch 67, CIFAR-10 Batch 4:  The Validation Cost is 1.47263
# The Validation Accuracy is 0.525
# Epoch 67, CIFAR-10 Batch 5:  The Validation Cost is 1.71556
# The Validation Accuracy is 0.325
# Epoch 68, CIFAR-10 Batch 1:  The Validation Cost is 1.46519
# The Validation Accuracy is 0.475
# Epoch 68, CIFAR-10 Batch 2:  The Validation Cost is 1.41176
# The Validation Accuracy is 0.55
# Epoch 68, CIFAR-10 Batch 3:  The Validation Cost is 1.41712
# The Validation Accuracy is 0.65
# Epoch 68, CIFAR-10 Batch 4:  The Validation Cost is 1.46761
# The Validation Accuracy is 0.5
# Epoch 68, CIFAR-10 Batch 5:  The Validation Cost is 1.6909
# The Validation Accuracy is 0.4
# Epoch 69, CIFAR-10 Batch 1:  The Validation Cost is 1.40798
# The Validation Accuracy is 0.5
# Epoch 69, CIFAR-10 Batch 2:  The Validation Cost is 1.40353
# The Validation Accuracy is 0.525
# Epoch 69, CIFAR-10 Batch 3:  The Validation Cost is 1.40488
# The Validation Accuracy is 0.675
# Epoch 69, CIFAR-10 Batch 4:  The Validation Cost is 1.48593
# The Validation Accuracy is 0.5
# Epoch 69, CIFAR-10 Batch 5:  The Validation Cost is 1.71066
# The Validation Accuracy is 0.425
# Epoch 70, CIFAR-10 Batch 1:  The Validation Cost is 1.3887
# The Validation Accuracy is 0.55
# Epoch 70, CIFAR-10 Batch 2:  The Validation Cost is 1.40466
# The Validation Accuracy is 0.55
# Epoch 70, CIFAR-10 Batch 3:  The Validation Cost is 1.446
# The Validation Accuracy is 0.675
# Epoch 70, CIFAR-10 Batch 4:  The Validation Cost is 1.47896
# The Validation Accuracy is 0.525
# Epoch 70, CIFAR-10 Batch 5:  The Validation Cost is 1.65601
# The Validation Accuracy is 0.45
# Epoch 71, CIFAR-10 Batch 1:  The Validation Cost is 1.41956
# The Validation Accuracy is 0.45
# Epoch 71, CIFAR-10 Batch 2:  The Validation Cost is 1.34658
# The Validation Accuracy is 0.575
# Epoch 71, CIFAR-10 Batch 3:  The Validation Cost is 1.44289
# The Validation Accuracy is 0.675
# Epoch 71, CIFAR-10 Batch 4:  The Validation Cost is 1.44129
# The Validation Accuracy is 0.525
# Epoch 71, CIFAR-10 Batch 5:  The Validation Cost is 1.66913
# The Validation Accuracy is 0.4
# Epoch 72, CIFAR-10 Batch 1:  The Validation Cost is 1.37584
# The Validation Accuracy is 0.525
# Epoch 72, CIFAR-10 Batch 2:  The Validation Cost is 1.35846
# The Validation Accuracy is 0.525
# Epoch 72, CIFAR-10 Batch 3:  The Validation Cost is 1.432
# The Validation Accuracy is 0.675
# Epoch 72, CIFAR-10 Batch 4:  The Validation Cost is 1.45666
# The Validation Accuracy is 0.475
# Epoch 72, CIFAR-10 Batch 5:  The Validation Cost is 1.63819
# The Validation Accuracy is 0.425
# Epoch 73, CIFAR-10 Batch 1:  The Validation Cost is 1.43393
# The Validation Accuracy is 0.425
# Epoch 73, CIFAR-10 Batch 2:  The Validation Cost is 1.35944
# The Validation Accuracy is 0.55
# Epoch 73, CIFAR-10 Batch 3:  The Validation Cost is 1.4356
# The Validation Accuracy is 0.675
# Epoch 73, CIFAR-10 Batch 4:  The Validation Cost is 1.44131
# The Validation Accuracy is 0.525
# Epoch 73, CIFAR-10 Batch 5:  The Validation Cost is 1.66166
# The Validation Accuracy is 0.375
# Epoch 74, CIFAR-10 Batch 1:  The Validation Cost is 1.38863
# The Validation Accuracy is 0.475
# Epoch 74, CIFAR-10 Batch 2:  The Validation Cost is 1.36564
# The Validation Accuracy is 0.575
# Epoch 74, CIFAR-10 Batch 3:  The Validation Cost is 1.37982
# The Validation Accuracy is 0.675
# Epoch 74, CIFAR-10 Batch 4:  The Validation Cost is 1.46124
# The Validation Accuracy is 0.55
# Epoch 74, CIFAR-10 Batch 5:  The Validation Cost is 1.64989
# The Validation Accuracy is 0.4
# Epoch 75, CIFAR-10 Batch 1:  The Validation Cost is 1.37357
# The Validation Accuracy is 0.475
# Epoch 75, CIFAR-10 Batch 2:  The Validation Cost is 1.35471
# The Validation Accuracy is 0.6
# Epoch 75, CIFAR-10 Batch 3:  The Validation Cost is 1.38781
# The Validation Accuracy is 0.675
# Epoch 75, CIFAR-10 Batch 4:  The Validation Cost is 1.44409
# The Validation Accuracy is 0.55
# Epoch 75, CIFAR-10 Batch 5:  The Validation Cost is 1.62771
# The Validation Accuracy is 0.475
# Epoch 76, CIFAR-10 Batch 1:  The Validation Cost is 1.35007
# The Validation Accuracy is 0.5
# Epoch 76, CIFAR-10 Batch 2:  The Validation Cost is 1.35978
# The Validation Accuracy is 0.575
# Epoch 76, CIFAR-10 Batch 3:  The Validation Cost is 1.38233
# The Validation Accuracy is 0.7
# Epoch 76, CIFAR-10 Batch 4:  The Validation Cost is 1.39547
# The Validation Accuracy is 0.6
# Epoch 76, CIFAR-10 Batch 5:  The Validation Cost is 1.56556
# The Validation Accuracy is 0.425
# Epoch 77, CIFAR-10 Batch 1:  The Validation Cost is 1.37219
# The Validation Accuracy is 0.475
# Epoch 77, CIFAR-10 Batch 2:  The Validation Cost is 1.3647
# The Validation Accuracy is 0.575
# Epoch 77, CIFAR-10 Batch 3:  The Validation Cost is 1.39335
# The Validation Accuracy is 0.675
# Epoch 77, CIFAR-10 Batch 4:  The Validation Cost is 1.41029
# The Validation Accuracy is 0.55
# Epoch 77, CIFAR-10 Batch 5:  The Validation Cost is 1.62836
# The Validation Accuracy is 0.4
# Epoch 78, CIFAR-10 Batch 1:  The Validation Cost is 1.30901
# The Validation Accuracy is 0.575
# Epoch 78, CIFAR-10 Batch 2:  The Validation Cost is 1.348
# The Validation Accuracy is 0.625
# Epoch 78, CIFAR-10 Batch 3:  The Validation Cost is 1.41451
# The Validation Accuracy is 0.7
# Epoch 78, CIFAR-10 Batch 4:  The Validation Cost is 1.41468
# The Validation Accuracy is 0.55
# Epoch 78, CIFAR-10 Batch 5:  The Validation Cost is 1.58389
# The Validation Accuracy is 0.45
# Epoch 79, CIFAR-10 Batch 1:  The Validation Cost is 1.31107
# The Validation Accuracy is 0.575
# Epoch 79, CIFAR-10 Batch 2:  The Validation Cost is 1.38672
# The Validation Accuracy is 0.525
# Epoch 79, CIFAR-10 Batch 3:  The Validation Cost is 1.38032
# The Validation Accuracy is 0.675
# Epoch 79, CIFAR-10 Batch 4:  The Validation Cost is 1.38761
# The Validation Accuracy is 0.55
# Epoch 79, CIFAR-10 Batch 5:  The Validation Cost is 1.55152
# The Validation Accuracy is 0.5
# Epoch 80, CIFAR-10 Batch 1:  The Validation Cost is 1.29658
# The Validation Accuracy is 0.575
# Epoch 80, CIFAR-10 Batch 2:  The Validation Cost is 1.32504
# The Validation Accuracy is 0.55
# Epoch 80, CIFAR-10 Batch 3:  The Validation Cost is 1.33865
# The Validation Accuracy is 0.7
# Epoch 80, CIFAR-10 Batch 4:  The Validation Cost is 1.38647
# The Validation Accuracy is 0.575
# Epoch 80, CIFAR-10 Batch 5:  The Validation Cost is 1.57615
# The Validation Accuracy is 0.425
# Epoch 81, CIFAR-10 Batch 1:  The Validation Cost is 1.3031
# The Validation Accuracy is 0.625
# Epoch 81, CIFAR-10 Batch 2:  The Validation Cost is 1.32598
# The Validation Accuracy is 0.6
# Epoch 81, CIFAR-10 Batch 3:  The Validation Cost is 1.34846
# The Validation Accuracy is 0.675
# Epoch 81, CIFAR-10 Batch 4:  The Validation Cost is 1.389
# The Validation Accuracy is 0.55
# Epoch 81, CIFAR-10 Batch 5:  The Validation Cost is 1.59511
# The Validation Accuracy is 0.475
# Epoch 82, CIFAR-10 Batch 1:  The Validation Cost is 1.30239
# The Validation Accuracy is 0.65
# Epoch 82, CIFAR-10 Batch 2:  The Validation Cost is 1.30896
# The Validation Accuracy is 0.625
# Epoch 82, CIFAR-10 Batch 3:  The Validation Cost is 1.35262
# The Validation Accuracy is 0.7
# Epoch 82, CIFAR-10 Batch 4:  The Validation Cost is 1.39039
# The Validation Accuracy is 0.55
# Epoch 82, CIFAR-10 Batch 5:  The Validation Cost is 1.55656
# The Validation Accuracy is 0.475
# Epoch 83, CIFAR-10 Batch 1:  The Validation Cost is 1.29122
# The Validation Accuracy is 0.575
# Epoch 83, CIFAR-10 Batch 2:  The Validation Cost is 1.34625
# The Validation Accuracy is 0.6
# Epoch 83, CIFAR-10 Batch 3:  The Validation Cost is 1.31996
# The Validation Accuracy is 0.675
# Epoch 83, CIFAR-10 Batch 4:  The Validation Cost is 1.36493
# The Validation Accuracy is 0.55
# Epoch 83, CIFAR-10 Batch 5:  The Validation Cost is 1.53735
# The Validation Accuracy is 0.475
# Epoch 84, CIFAR-10 Batch 1:  The Validation Cost is 1.30699
# The Validation Accuracy is 0.6
# Epoch 84, CIFAR-10 Batch 2:  The Validation Cost is 1.3154
# The Validation Accuracy is 0.65
# Epoch 84, CIFAR-10 Batch 3:  The Validation Cost is 1.34569
# The Validation Accuracy is 0.65
# Epoch 84, CIFAR-10 Batch 4:  The Validation Cost is 1.372
# The Validation Accuracy is 0.55
# Epoch 84, CIFAR-10 Batch 5:  The Validation Cost is 1.55347
# The Validation Accuracy is 0.425
# Epoch 85, CIFAR-10 Batch 1:  The Validation Cost is 1.28317
# The Validation Accuracy is 0.6
# Epoch 85, CIFAR-10 Batch 2:  The Validation Cost is 1.31135
# The Validation Accuracy is 0.575
# Epoch 85, CIFAR-10 Batch 3:  The Validation Cost is 1.35693
# The Validation Accuracy is 0.675
# Epoch 85, CIFAR-10 Batch 4:  The Validation Cost is 1.36241
# The Validation Accuracy is 0.525
# Epoch 85, CIFAR-10 Batch 5:  The Validation Cost is 1.57472
# The Validation Accuracy is 0.475
# Epoch 86, CIFAR-10 Batch 1:  The Validation Cost is 1.30409
# The Validation Accuracy is 0.525
# Epoch 86, CIFAR-10 Batch 2:  The Validation Cost is 1.34572
# The Validation Accuracy is 0.55
# Epoch 86, CIFAR-10 Batch 3:  The Validation Cost is 1.3315
# The Validation Accuracy is 0.7
# Epoch 86, CIFAR-10 Batch 4:  The Validation Cost is 1.36155
# The Validation Accuracy is 0.525
# Epoch 86, CIFAR-10 Batch 5:  The Validation Cost is 1.5441
# The Validation Accuracy is 0.475
# Epoch 87, CIFAR-10 Batch 1:  The Validation Cost is 1.28253
# The Validation Accuracy is 0.6
# Epoch 87, CIFAR-10 Batch 2:  The Validation Cost is 1.30403
# The Validation Accuracy is 0.575
# Epoch 87, CIFAR-10 Batch 3:  The Validation Cost is 1.31047
# The Validation Accuracy is 0.7
# Epoch 87, CIFAR-10 Batch 4:  The Validation Cost is 1.34626
# The Validation Accuracy is 0.525
# Epoch 87, CIFAR-10 Batch 5:  The Validation Cost is 1.54178
# The Validation Accuracy is 0.425
# Epoch 88, CIFAR-10 Batch 1:  The Validation Cost is 1.25313
# The Validation Accuracy is 0.65
# Epoch 88, CIFAR-10 Batch 2:  The Validation Cost is 1.30798
# The Validation Accuracy is 0.65
# Epoch 88, CIFAR-10 Batch 3:  The Validation Cost is 1.37408
# The Validation Accuracy is 0.675
# Epoch 88, CIFAR-10 Batch 4:  The Validation Cost is 1.34985
# The Validation Accuracy is 0.55
# Epoch 88, CIFAR-10 Batch 5:  The Validation Cost is 1.52966
# The Validation Accuracy is 0.45
# Epoch 89, CIFAR-10 Batch 1:  The Validation Cost is 1.27456
# The Validation Accuracy is 0.675
# Epoch 89, CIFAR-10 Batch 2:  The Validation Cost is 1.30464
# The Validation Accuracy is 0.6
# Epoch 89, CIFAR-10 Batch 3:  The Validation Cost is 1.28871
# The Validation Accuracy is 0.7
# Epoch 89, CIFAR-10 Batch 4:  The Validation Cost is 1.35243
# The Validation Accuracy is 0.55
# Epoch 89, CIFAR-10 Batch 5:  The Validation Cost is 1.52394
# The Validation Accuracy is 0.425
# Epoch 90, CIFAR-10 Batch 1:  The Validation Cost is 1.25285
# The Validation Accuracy is 0.625
# Epoch 90, CIFAR-10 Batch 2:  The Validation Cost is 1.30828
# The Validation Accuracy is 0.6
# Epoch 90, CIFAR-10 Batch 3:  The Validation Cost is 1.32885
# The Validation Accuracy is 0.675
# Epoch 90, CIFAR-10 Batch 4:  The Validation Cost is 1.34601
# The Validation Accuracy is 0.575
# Epoch 90, CIFAR-10 Batch 5:  The Validation Cost is 1.51544
# The Validation Accuracy is 0.5
# Epoch 91, CIFAR-10 Batch 1:  The Validation Cost is 1.25152
# The Validation Accuracy is 0.65
# Epoch 91, CIFAR-10 Batch 2:  The Validation Cost is 1.31612
# The Validation Accuracy is 0.575
# Epoch 91, CIFAR-10 Batch 3:  The Validation Cost is 1.30545
# The Validation Accuracy is 0.725
# Epoch 91, CIFAR-10 Batch 4:  The Validation Cost is 1.33698
# The Validation Accuracy is 0.525
# Epoch 91, CIFAR-10 Batch 5:  The Validation Cost is 1.48686
# The Validation Accuracy is 0.5
# Epoch 92, CIFAR-10 Batch 1:  The Validation Cost is 1.23274
# The Validation Accuracy is 0.65
# Epoch 92, CIFAR-10 Batch 2:  The Validation Cost is 1.2668
# The Validation Accuracy is 0.65
# Epoch 92, CIFAR-10 Batch 3:  The Validation Cost is 1.27981
# The Validation Accuracy is 0.725
# Epoch 92, CIFAR-10 Batch 4:  The Validation Cost is 1.31434
# The Validation Accuracy is 0.575
# Epoch 92, CIFAR-10 Batch 5:  The Validation Cost is 1.53203
# The Validation Accuracy is 0.525
# Epoch 93, CIFAR-10 Batch 1:  The Validation Cost is 1.21103
# The Validation Accuracy is 0.625
# Epoch 93, CIFAR-10 Batch 2:  The Validation Cost is 1.22973
# The Validation Accuracy is 0.625
# Epoch 93, CIFAR-10 Batch 3:  The Validation Cost is 1.28243
# The Validation Accuracy is 0.725
# Epoch 93, CIFAR-10 Batch 4:  The Validation Cost is 1.37015
# The Validation Accuracy is 0.575
# Epoch 93, CIFAR-10 Batch 5:  The Validation Cost is 1.50678
# The Validation Accuracy is 0.5
# Epoch 94, CIFAR-10 Batch 1:  The Validation Cost is 1.20795
# The Validation Accuracy is 0.625
# Epoch 94, CIFAR-10 Batch 2:  The Validation Cost is 1.25834
# The Validation Accuracy is 0.575
# Epoch 94, CIFAR-10 Batch 3:  The Validation Cost is 1.26875
# The Validation Accuracy is 0.7
# Epoch 94, CIFAR-10 Batch 4:  The Validation Cost is 1.34002
# The Validation Accuracy is 0.55
# Epoch 94, CIFAR-10 Batch 5:  The Validation Cost is 1.5058
# The Validation Accuracy is 0.475
# Epoch 95, CIFAR-10 Batch 1:  The Validation Cost is 1.19349
# The Validation Accuracy is 0.65
# Epoch 95, CIFAR-10 Batch 2:  The Validation Cost is 1.27375
# The Validation Accuracy is 0.6
# Epoch 95, CIFAR-10 Batch 3:  The Validation Cost is 1.24711
# The Validation Accuracy is 0.7
# Epoch 95, CIFAR-10 Batch 4:  The Validation Cost is 1.37412
# The Validation Accuracy is 0.55
# Epoch 95, CIFAR-10 Batch 5:  The Validation Cost is 1.47698
# The Validation Accuracy is 0.475
# Epoch 96, CIFAR-10 Batch 1:  The Validation Cost is 1.22005
# The Validation Accuracy is 0.675
# Epoch 96, CIFAR-10 Batch 2:  The Validation Cost is 1.2306
# The Validation Accuracy is 0.675
# Epoch 96, CIFAR-10 Batch 3:  The Validation Cost is 1.24375
# The Validation Accuracy is 0.7
# Epoch 96, CIFAR-10 Batch 4:  The Validation Cost is 1.35931
# The Validation Accuracy is 0.55
# Epoch 96, CIFAR-10 Batch 5:  The Validation Cost is 1.49877
# The Validation Accuracy is 0.5
# Epoch 97, CIFAR-10 Batch 1:  The Validation Cost is 1.18197
# The Validation Accuracy is 0.625
# Epoch 97, CIFAR-10 Batch 2:  The Validation Cost is 1.2467
# The Validation Accuracy is 0.65
# Epoch 97, CIFAR-10 Batch 3:  The Validation Cost is 1.25349
# The Validation Accuracy is 0.725
# Epoch 97, CIFAR-10 Batch 4:  The Validation Cost is 1.32803
# The Validation Accuracy is 0.525
# Epoch 97, CIFAR-10 Batch 5:  The Validation Cost is 1.49075
# The Validation Accuracy is 0.5
# Epoch 98, CIFAR-10 Batch 1:  The Validation Cost is 1.19443
# The Validation Accuracy is 0.675
# Epoch 98, CIFAR-10 Batch 2:  The Validation Cost is 1.23969
# The Validation Accuracy is 0.7
# Epoch 98, CIFAR-10 Batch 3:  The Validation Cost is 1.26315
# The Validation Accuracy is 0.725
# Epoch 98, CIFAR-10 Batch 4:  The Validation Cost is 1.29031
# The Validation Accuracy is 0.6
# Epoch 98, CIFAR-10 Batch 5:  The Validation Cost is 1.50365
# The Validation Accuracy is 0.5
# Epoch 99, CIFAR-10 Batch 1:  The Validation Cost is 1.19977
# The Validation Accuracy is 0.65
# Epoch 99, CIFAR-10 Batch 2:  The Validation Cost is 1.24193
# The Validation Accuracy is 0.65
# Epoch 99, CIFAR-10 Batch 3:  The Validation Cost is 1.22627
# The Validation Accuracy is 0.725
# Epoch 99, CIFAR-10 Batch 4:  The Validation Cost is 1.32845
# The Validation Accuracy is 0.55
# Epoch 99, CIFAR-10 Batch 5:  The Validation Cost is 1.46497
# The Validation Accuracy is 0.5
# Epoch 100, CIFAR-10 Batch 1:  The Validation Cost is 1.18905
# The Validation Accuracy is 0.575
# Epoch 100, CIFAR-10 Batch 2:  The Validation Cost is 1.212
# The Validation Accuracy is 0.675
# Epoch 100, CIFAR-10 Batch 3:  The Validation Cost is 1.2534
# The Validation Accuracy is 0.725
# Epoch 100, CIFAR-10 Batch 4:  The Validation Cost is 1.31698
# The Validation Accuracy is 0.575
# Epoch 100, CIFAR-10 Batch 5:  The Validation Cost is 1.52811
# The Validation Accuracy is 0.475

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.18552215189873417

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
