# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    #There are several ways to normalize the data. Here I choose the simple method : (x - min(X)) / (max(X) - min(x))
    
#     image_normalize = np.zeros((len(x),32,32,3))
#     m = 0
#     for image in x:
#         for i in range(3):
#             image_ = image[:,:,i]
#             image_max = np.max(np.max(image_))
#             image_min = np.max(np.min(image_))
#             image[:,:,i] = (image_ - image_min) / float(image_max - image_min)
#         image_normalize[m,:,:,:] = image
#         m += 1
#     return image_normalize
    x_min = np.min(x)
    x_max = np.max(x)
    scale = x_max - x_min
    return (x - x_min) / scale
        
            

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    from sklearn.preprocessing import OneHotEncoder
    one_hot_encode = OneHotEncoder().fit(np.arange(10).reshape(-1,1))
    one_hot_out = one_hot_encode.transform(np.array(x).reshape(-1,1)).toarray()
    return one_hot_out

    """
    An another way of one hot encoder
    
    from sklearn.preprocessing import LabelBinarizer
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(10)
    return label_binarizer.transform(x)
    """


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, shape=[None, n_classes], name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, name='keep_prob' )
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3],
                                            conv_num_outputs], stddev=0.05))
    biases = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, biases)
    conv_layer = tf.nn.relu(conv_layer)
    pool_layer = tf.nn.max_pool(conv_layer, ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                                strides=[1, pool_strides[0],pool_strides[1], 1], padding='SAME')
    
    
    return pool_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
#     layer_shape = x_tensor.get_shape()
#     num_features = layer_shape[1:4].num_elements()
#     layer_flat = tf.reshape(x_tensor, [-1, num_features])
    
#     return layer_flat

    return tf.contrib.layers.flatten(x_tensor)
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
#     weights = tf.Variable(tf.random_normal(shape=[x_tensor.get_shape().as_list()[1], num_outputs]))
#     biases = tf.Variable(tf.zeros(num_outputs))
#     fully_conn = tf.add(tf.matmul(x_tensor, weights), biases)
#     fully_conn = tf.nn.relu(fully_conn)
#     return fully_conn
    return tf.layers.dense(x_tensor, num_outputs, activation=tf.nn.relu)



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
#     weights = tf.Variable(tf.random_normal(shape=[x_tensor.get_shape().as_list()[1], num_outputs]))
#     biases = tf.Variable(tf.zeros(num_outputs))
#     logits = tf.add(tf.matmul(x_tensor, weights), biases)
#     return logits
    return tf.layers.dense(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv_1 = conv2d_maxpool(x, 8, conv_ksize=[5,5], conv_strides=[1,1], pool_ksize=[2,2], pool_strides=[2,2])
#     conv_1 = tf.nn.dropout(conv_1, keep_prob)
    conv_2 = conv2d_maxpool(conv_1, 16, conv_ksize=[3,3], conv_strides=[1,1], pool_ksize=[2,2], pool_strides=[1,1])
#     conv_2 = tf.nn.dropout(conv_2, keep_prob)
    conv_3 = conv2d_maxpool(conv_2, 96, conv_ksize=[1,1], conv_strides=[1,1], pool_ksize=[1,1], pool_strides=[1,1])
    conv_3 = tf.nn.dropout(conv_3, keep_prob)
#     # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(conv_3)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc1 = fully_conn(flatten_layer, 512)
    fc2 = fully_conn(fc1, 256)
    fc3 = fully_conn(fc2, 128)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    logits = output(fc3, 10)
    
    # TODO: return output
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print('The Loss is ' + str(sess.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.})))
    print('The Validation Accuracy is ' + str(session.run(accuracy, 
                                                          feed_dict={x:valid_features, y:valid_labels, keep_prob:1.})))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  The Loss is 2.05393
# The Validation Accuracy is 0.2776
# Epoch  2, CIFAR-10 Batch 1:  The Loss is 1.93158
# The Validation Accuracy is 0.3496
# Epoch  3, CIFAR-10 Batch 1:  The Loss is 1.77213
# The Validation Accuracy is 0.3886
# Epoch  4, CIFAR-10 Batch 1:  The Loss is 1.6859
# The Validation Accuracy is 0.404
# Epoch  5, CIFAR-10 Batch 1:  The Loss is 1.61069
# The Validation Accuracy is 0.4098
# Epoch  6, CIFAR-10 Batch 1:  The Loss is 1.52498
# The Validation Accuracy is 0.461
# Epoch  7, CIFAR-10 Batch 1:  The Loss is 1.45123
# The Validation Accuracy is 0.4762
# Epoch  8, CIFAR-10 Batch 1:  The Loss is 1.40431
# The Validation Accuracy is 0.4754
# Epoch  9, CIFAR-10 Batch 1:  The Loss is 1.32549
# The Validation Accuracy is 0.486
# Epoch 10, CIFAR-10 Batch 1:  The Loss is 1.28104
# The Validation Accuracy is 0.498
# Epoch 11, CIFAR-10 Batch 1:  The Loss is 1.18767
# The Validation Accuracy is 0.51
# Epoch 12, CIFAR-10 Batch 1:  The Loss is 1.12606
# The Validation Accuracy is 0.5158
# Epoch 13, CIFAR-10 Batch 1:  The Loss is 1.06892
# The Validation Accuracy is 0.5192
# Epoch 14, CIFAR-10 Batch 1:  The Loss is 0.99404
# The Validation Accuracy is 0.5244
# Epoch 15, CIFAR-10 Batch 1:  The Loss is 0.93391
# The Validation Accuracy is 0.5306
# Epoch 16, CIFAR-10 Batch 1:  The Loss is 0.873989
# The Validation Accuracy is 0.543
# Epoch 17, CIFAR-10 Batch 1:  The Loss is 0.815441
# The Validation Accuracy is 0.5446
# Epoch 18, CIFAR-10 Batch 1:  The Loss is 0.7518
# The Validation Accuracy is 0.5486
# Epoch 19, CIFAR-10 Batch 1:  The Loss is 0.715491
# The Validation Accuracy is 0.544
# Epoch 20, CIFAR-10 Batch 1:  The Loss is 0.700201
# The Validation Accuracy is 0.5242
# Epoch 21, CIFAR-10 Batch 1:  The Loss is 0.619164
# The Validation Accuracy is 0.5518
# Epoch 22, CIFAR-10 Batch 1:  The Loss is 0.582939
# The Validation Accuracy is 0.5454
# Epoch 23, CIFAR-10 Batch 1:  The Loss is 0.717828
# The Validation Accuracy is 0.5118
# Epoch 24, CIFAR-10 Batch 1:  The Loss is 0.534915
# The Validation Accuracy is 0.5466
# Epoch 25, CIFAR-10 Batch 1:  The Loss is 0.434188
# The Validation Accuracy is 0.5448
# Epoch 26, CIFAR-10 Batch 1:  The Loss is 0.389264
# The Validation Accuracy is 0.543
# Epoch 27, CIFAR-10 Batch 1:  The Loss is 0.410672
# The Validation Accuracy is 0.518
# Epoch 28, CIFAR-10 Batch 1:  The Loss is 0.344532
# The Validation Accuracy is 0.5502
# Epoch 29, CIFAR-10 Batch 1:  The Loss is 0.311826
# The Validation Accuracy is 0.5672
# Epoch 30, CIFAR-10 Batch 1:  The Loss is 0.270481
# The Validation Accuracy is 0.5566
# Epoch 31, CIFAR-10 Batch 1:  The Loss is 0.261201
# The Validation Accuracy is 0.539
# Epoch 32, CIFAR-10 Batch 1:  The Loss is 0.243537
# The Validation Accuracy is 0.5482
# Epoch 33, CIFAR-10 Batch 1:  The Loss is 0.199453
# The Validation Accuracy is 0.5494
# Epoch 34, CIFAR-10 Batch 1:  The Loss is 0.209983
# The Validation Accuracy is 0.546
# Epoch 35, CIFAR-10 Batch 1:  The Loss is 0.238213
# The Validation Accuracy is 0.506
# Epoch 36, CIFAR-10 Batch 1:  The Loss is 0.192828
# The Validation Accuracy is 0.5412
# Epoch 37, CIFAR-10 Batch 1:  The Loss is 0.110129
# The Validation Accuracy is 0.541
# Epoch 38, CIFAR-10 Batch 1:  The Loss is 0.112408
# The Validation Accuracy is 0.5554
# Epoch 39, CIFAR-10 Batch 1:  The Loss is 0.117004
# The Validation Accuracy is 0.5324
# Epoch 40, CIFAR-10 Batch 1:  The Loss is 0.138745
# The Validation Accuracy is 0.531
# Epoch 41, CIFAR-10 Batch 1:  The Loss is 0.197768
# The Validation Accuracy is 0.5208
# Epoch 42, CIFAR-10 Batch 1:  The Loss is 0.15399
# The Validation Accuracy is 0.5258
# Epoch 43, CIFAR-10 Batch 1:  The Loss is 0.118379
# The Validation Accuracy is 0.542
# Epoch 44, CIFAR-10 Batch 1:  The Loss is 0.0672776
# The Validation Accuracy is 0.552
# Epoch 45, CIFAR-10 Batch 1:  The Loss is 0.106748
# The Validation Accuracy is 0.523
# Epoch 46, CIFAR-10 Batch 1:  The Loss is 0.122818
# The Validation Accuracy is 0.538
# Epoch 47, CIFAR-10 Batch 1:  The Loss is 0.0802974
# The Validation Accuracy is 0.5352
# Epoch 48, CIFAR-10 Batch 1:  The Loss is 0.0322437
# The Validation Accuracy is 0.5496
# Epoch 49, CIFAR-10 Batch 1:  The Loss is 0.0346519
# The Validation Accuracy is 0.5352
# Epoch 50, CIFAR-10 Batch 1:  The Loss is 0.0153167
# The Validation Accuracy is 0.5648
# Epoch 51, CIFAR-10 Batch 1:  The Loss is 0.0165585
# The Validation Accuracy is 0.554
# Epoch 52, CIFAR-10 Batch 1:  The Loss is 0.0468817
# The Validation Accuracy is 0.5332
# Epoch 53, CIFAR-10 Batch 1:  The Loss is 0.0117105
# The Validation Accuracy is 0.564
# Epoch 54, CIFAR-10 Batch 1:  The Loss is 0.016213
# The Validation Accuracy is 0.5688
# Epoch 55, CIFAR-10 Batch 1:  The Loss is 0.00600516
# The Validation Accuracy is 0.5738
# Epoch 56, CIFAR-10 Batch 1:  The Loss is 0.0049679
# The Validation Accuracy is 0.5666
# Epoch 57, CIFAR-10 Batch 1:  The Loss is 0.0158125
# The Validation Accuracy is 0.547
# Epoch 58, CIFAR-10 Batch 1:  The Loss is 0.0465011
# The Validation Accuracy is 0.5292
# Epoch 59, CIFAR-10 Batch 1:  The Loss is 0.0414187
# The Validation Accuracy is 0.5266
# Epoch 60, CIFAR-10 Batch 1:  The Loss is 0.0384574
# The Validation Accuracy is 0.5418
# Epoch 61, CIFAR-10 Batch 1:  The Loss is 0.00704464
# The Validation Accuracy is 0.5698
# Epoch 62, CIFAR-10 Batch 1:  The Loss is 0.00599732
# The Validation Accuracy is 0.569
# Epoch 63, CIFAR-10 Batch 1:  The Loss is 0.0032191
# The Validation Accuracy is 0.5688
# Epoch 64, CIFAR-10 Batch 1:  The Loss is 0.00172966
# The Validation Accuracy is 0.57
# Epoch 65, CIFAR-10 Batch 1:  The Loss is 0.00159078
# The Validation Accuracy is 0.5666
# Epoch 66, CIFAR-10 Batch 1:  The Loss is 0.00183447
# The Validation Accuracy is 0.5652
# Epoch 67, CIFAR-10 Batch 1:  The Loss is 0.00272085
# The Validation Accuracy is 0.5604
# Epoch 68, CIFAR-10 Batch 1:  The Loss is 0.00114184
# The Validation Accuracy is 0.5678
# Epoch 69, CIFAR-10 Batch 1:  The Loss is 0.000775093
# The Validation Accuracy is 0.5688
# Epoch 70, CIFAR-10 Batch 1:  The Loss is 0.000934415
# The Validation Accuracy is 0.5644
# Epoch 71, CIFAR-10 Batch 1:  The Loss is 0.00148832
# The Validation Accuracy is 0.567
# Epoch 72, CIFAR-10 Batch 1:  The Loss is 0.000549768
# The Validation Accuracy is 0.572
# Epoch 73, CIFAR-10 Batch 1:  The Loss is 0.000622369
# The Validation Accuracy is 0.5746
# Epoch 74, CIFAR-10 Batch 1:  The Loss is 0.000632503
# The Validation Accuracy is 0.5676
# Epoch 75, CIFAR-10 Batch 1:  The Loss is 0.000718286
# The Validation Accuracy is 0.568
# Epoch 76, CIFAR-10 Batch 1:  The Loss is 0.00125784
# The Validation Accuracy is 0.569
# Epoch 77, CIFAR-10 Batch 1:  The Loss is 0.000806706
# The Validation Accuracy is 0.5736
# Epoch 78, CIFAR-10 Batch 1:  The Loss is 0.00126583
# The Validation Accuracy is 0.5678
# Epoch 79, CIFAR-10 Batch 1:  The Loss is 0.00123255
# The Validation Accuracy is 0.561
# Epoch 80, CIFAR-10 Batch 1:  The Loss is 0.000633462
# The Validation Accuracy is 0.5648
# Epoch 81, CIFAR-10 Batch 1:  The Loss is 0.000370358
# The Validation Accuracy is 0.5678
# Epoch 82, CIFAR-10 Batch 1:  The Loss is 0.000909006
# The Validation Accuracy is 0.563
# Epoch 83, CIFAR-10 Batch 1:  The Loss is 0.000699381
# The Validation Accuracy is 0.5666
# Epoch 84, CIFAR-10 Batch 1:  The Loss is 0.00166859
# The Validation Accuracy is 0.564
# Epoch 85, CIFAR-10 Batch 1:  The Loss is 0.000897658
# The Validation Accuracy is 0.5638
# Epoch 86, CIFAR-10 Batch 1:  The Loss is 0.00118954
# The Validation Accuracy is 0.5646
# Epoch 87, CIFAR-10 Batch 1:  The Loss is 0.000719266
# The Validation Accuracy is 0.569
# Epoch 88, CIFAR-10 Batch 1:  The Loss is 0.000610904
# The Validation Accuracy is 0.5628
# Epoch 89, CIFAR-10 Batch 1:  The Loss is 0.00071792
# The Validation Accuracy is 0.5746
# Epoch 90, CIFAR-10 Batch 1:  The Loss is 0.00100305
# The Validation Accuracy is 0.5654
# Epoch 91, CIFAR-10 Batch 1:  The Loss is 0.00189626
# The Validation Accuracy is 0.5622
# Epoch 92, CIFAR-10 Batch 1:  The Loss is 0.000575312
# The Validation Accuracy is 0.5748
# Epoch 93, CIFAR-10 Batch 1:  The Loss is 0.000485796
# The Validation Accuracy is 0.5762
# Epoch 94, CIFAR-10 Batch 1:  The Loss is 0.00107012
# The Validation Accuracy is 0.5746
# Epoch 95, CIFAR-10 Batch 1:  The Loss is 0.0010491
# The Validation Accuracy is 0.5676
# Epoch 96, CIFAR-10 Batch 1:  The Loss is 0.000767709
# The Validation Accuracy is 0.5706
# Epoch 97, CIFAR-10 Batch 1:  The Loss is 0.000742301
# The Validation Accuracy is 0.571
# Epoch 98, CIFAR-10 Batch 1:  The Loss is 0.000426398
# The Validation Accuracy is 0.5702
# Epoch 99, CIFAR-10 Batch 1:  The Loss is 0.000392798
# The Validation Accuracy is 0.5692
# Epoch 100, CIFAR-10 Batch 1:  The Loss is 0.000834314
# The Validation Accuracy is 0.569

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  The Loss is 2.11799
# The Validation Accuracy is 0.2458
# Epoch  1, CIFAR-10 Batch 2:  The Loss is 1.88493
# The Validation Accuracy is 0.3038
# Epoch  1, CIFAR-10 Batch 3:  The Loss is 1.6385
# The Validation Accuracy is 0.3368
# Epoch  1, CIFAR-10 Batch 4:  The Loss is 1.5352
# The Validation Accuracy is 0.4056
# Epoch  1, CIFAR-10 Batch 5:  The Loss is 1.59542
# The Validation Accuracy is 0.4352
# Epoch  2, CIFAR-10 Batch 1:  The Loss is 1.64034
# The Validation Accuracy is 0.4288
# Epoch  2, CIFAR-10 Batch 2:  The Loss is 1.46713
# The Validation Accuracy is 0.452
# Epoch  2, CIFAR-10 Batch 3:  The Loss is 1.29141
# The Validation Accuracy is 0.47
# Epoch  2, CIFAR-10 Batch 4:  The Loss is 1.3247
# The Validation Accuracy is 0.4826
# Epoch  2, CIFAR-10 Batch 5:  The Loss is 1.38342
# The Validation Accuracy is 0.5002
# Epoch  3, CIFAR-10 Batch 1:  The Loss is 1.44955
# The Validation Accuracy is 0.493
# Epoch  3, CIFAR-10 Batch 2:  The Loss is 1.29378
# The Validation Accuracy is 0.5146
# Epoch  3, CIFAR-10 Batch 3:  The Loss is 1.15848
# The Validation Accuracy is 0.5148
# Epoch  3, CIFAR-10 Batch 4:  The Loss is 1.22804
# The Validation Accuracy is 0.5078
# Epoch  3, CIFAR-10 Batch 5:  The Loss is 1.25224
# The Validation Accuracy is 0.5324
# Epoch  4, CIFAR-10 Batch 1:  The Loss is 1.33077
# The Validation Accuracy is 0.5402
# Epoch  4, CIFAR-10 Batch 2:  The Loss is 1.19438
# The Validation Accuracy is 0.528
# Epoch  4, CIFAR-10 Batch 3:  The Loss is 1.05155
# The Validation Accuracy is 0.5436
# Epoch  4, CIFAR-10 Batch 4:  The Loss is 1.11307
# The Validation Accuracy is 0.541
# Epoch  4, CIFAR-10 Batch 5:  The Loss is 1.13349
# The Validation Accuracy is 0.5554
# Epoch  5, CIFAR-10 Batch 1:  The Loss is 1.22156
# The Validation Accuracy is 0.5702
# Epoch  5, CIFAR-10 Batch 2:  The Loss is 1.09122
# The Validation Accuracy is 0.5604
# Epoch  5, CIFAR-10 Batch 3:  The Loss is 0.949817
# The Validation Accuracy is 0.5784
# Epoch  5, CIFAR-10 Batch 4:  The Loss is 1.00191
# The Validation Accuracy is 0.5648
# Epoch  5, CIFAR-10 Batch 5:  The Loss is 1.02298
# The Validation Accuracy is 0.5778
# Epoch  6, CIFAR-10 Batch 1:  The Loss is 1.08931
# The Validation Accuracy is 0.5972
# Epoch  6, CIFAR-10 Batch 2:  The Loss is 1.01649
# The Validation Accuracy is 0.5762
# Epoch  6, CIFAR-10 Batch 3:  The Loss is 0.851894
# The Validation Accuracy is 0.5946
# Epoch  6, CIFAR-10 Batch 4:  The Loss is 0.914262
# The Validation Accuracy is 0.5842
# Epoch  6, CIFAR-10 Batch 5:  The Loss is 0.90904
# The Validation Accuracy is 0.607
# Epoch  7, CIFAR-10 Batch 1:  The Loss is 0.960187
# The Validation Accuracy is 0.6106
# Epoch  7, CIFAR-10 Batch 2:  The Loss is 0.914419
# The Validation Accuracy is 0.5992
# Epoch  7, CIFAR-10 Batch 3:  The Loss is 0.792973
# The Validation Accuracy is 0.6152
# Epoch  7, CIFAR-10 Batch 4:  The Loss is 0.793837
# The Validation Accuracy is 0.6106
# Epoch  7, CIFAR-10 Batch 5:  The Loss is 0.810112
# The Validation Accuracy is 0.6222
# Epoch  8, CIFAR-10 Batch 1:  The Loss is 0.864447
# The Validation Accuracy is 0.6146
# Epoch  8, CIFAR-10 Batch 2:  The Loss is 0.835969
# The Validation Accuracy is 0.6188
# Epoch  8, CIFAR-10 Batch 3:  The Loss is 0.689937
# The Validation Accuracy is 0.6314
# Epoch  8, CIFAR-10 Batch 4:  The Loss is 0.681025
# The Validation Accuracy is 0.6286
# Epoch  8, CIFAR-10 Batch 5:  The Loss is 0.677414
# The Validation Accuracy is 0.641
# Epoch  9, CIFAR-10 Batch 1:  The Loss is 0.776337
# The Validation Accuracy is 0.6228
# Epoch  9, CIFAR-10 Batch 2:  The Loss is 0.762957
# The Validation Accuracy is 0.6218
# Epoch  9, CIFAR-10 Batch 3:  The Loss is 0.625438
# The Validation Accuracy is 0.63
# Epoch  9, CIFAR-10 Batch 4:  The Loss is 0.552724
# The Validation Accuracy is 0.65
# Epoch  9, CIFAR-10 Batch 5:  The Loss is 0.594903
# The Validation Accuracy is 0.6366
# Epoch 10, CIFAR-10 Batch 1:  The Loss is 0.67189
# The Validation Accuracy is 0.6392
# Epoch 10, CIFAR-10 Batch 2:  The Loss is 0.64049
# The Validation Accuracy is 0.6402
# Epoch 10, CIFAR-10 Batch 3:  The Loss is 0.601346
# The Validation Accuracy is 0.6176
# Epoch 10, CIFAR-10 Batch 4:  The Loss is 0.486703
# The Validation Accuracy is 0.65
# Epoch 10, CIFAR-10 Batch 5:  The Loss is 0.515094
# The Validation Accuracy is 0.646
# Epoch 11, CIFAR-10 Batch 1:  The Loss is 0.570565
# The Validation Accuracy is 0.6336
# Epoch 11, CIFAR-10 Batch 2:  The Loss is 0.613617
# The Validation Accuracy is 0.622
# Epoch 11, CIFAR-10 Batch 3:  The Loss is 0.496276
# The Validation Accuracy is 0.6352
# Epoch 11, CIFAR-10 Batch 4:  The Loss is 0.454845
# The Validation Accuracy is 0.6378
# Epoch 11, CIFAR-10 Batch 5:  The Loss is 0.495039
# The Validation Accuracy is 0.6478
# Epoch 12, CIFAR-10 Batch 1:  The Loss is 0.487713
# The Validation Accuracy is 0.6332
# Epoch 12, CIFAR-10 Batch 2:  The Loss is 0.516427
# The Validation Accuracy is 0.6306
# Epoch 12, CIFAR-10 Batch 3:  The Loss is 0.424462
# The Validation Accuracy is 0.6274
# Epoch 12, CIFAR-10 Batch 4:  The Loss is 0.376851
# The Validation Accuracy is 0.6436
# Epoch 12, CIFAR-10 Batch 5:  The Loss is 0.351278
# The Validation Accuracy is 0.661
# Epoch 13, CIFAR-10 Batch 1:  The Loss is 0.350336
# The Validation Accuracy is 0.6424
# Epoch 13, CIFAR-10 Batch 2:  The Loss is 0.470745
# The Validation Accuracy is 0.6104
# Epoch 13, CIFAR-10 Batch 3:  The Loss is 0.371665
# The Validation Accuracy is 0.637
# Epoch 13, CIFAR-10 Batch 4:  The Loss is 0.333149
# The Validation Accuracy is 0.6532
# Epoch 13, CIFAR-10 Batch 5:  The Loss is 0.300174
# The Validation Accuracy is 0.6514
# Epoch 14, CIFAR-10 Batch 1:  The Loss is 0.29971
# The Validation Accuracy is 0.6402
# Epoch 14, CIFAR-10 Batch 2:  The Loss is 0.337701
# The Validation Accuracy is 0.6354
# Epoch 14, CIFAR-10 Batch 3:  The Loss is 0.288109
# The Validation Accuracy is 0.6588
# Epoch 14, CIFAR-10 Batch 4:  The Loss is 0.249212
# The Validation Accuracy is 0.6648
# Epoch 14, CIFAR-10 Batch 5:  The Loss is 0.225975
# The Validation Accuracy is 0.645
# Epoch 15, CIFAR-10 Batch 1:  The Loss is 0.22982
# The Validation Accuracy is 0.6312
# Epoch 15, CIFAR-10 Batch 2:  The Loss is 0.293561
# The Validation Accuracy is 0.6276
# Epoch 15, CIFAR-10 Batch 3:  The Loss is 0.234686
# The Validation Accuracy is 0.654
# Epoch 15, CIFAR-10 Batch 4:  The Loss is 0.197369
# The Validation Accuracy is 0.6514
# Epoch 15, CIFAR-10 Batch 5:  The Loss is 0.155049
# The Validation Accuracy is 0.6442
# Epoch 16, CIFAR-10 Batch 1:  The Loss is 0.195338
# The Validation Accuracy is 0.6358
# Epoch 16, CIFAR-10 Batch 2:  The Loss is 0.20113
# The Validation Accuracy is 0.6338
# Epoch 16, CIFAR-10 Batch 3:  The Loss is 0.212424
# The Validation Accuracy is 0.6304
# Epoch 16, CIFAR-10 Batch 4:  The Loss is 0.147725
# The Validation Accuracy is 0.6506
# Epoch 16, CIFAR-10 Batch 5:  The Loss is 0.130046
# The Validation Accuracy is 0.6568
# Epoch 17, CIFAR-10 Batch 1:  The Loss is 0.17904
# The Validation Accuracy is 0.6146
# Epoch 17, CIFAR-10 Batch 2:  The Loss is 0.152347
# The Validation Accuracy is 0.6576
# Epoch 17, CIFAR-10 Batch 3:  The Loss is 0.13124
# The Validation Accuracy is 0.6462
# Epoch 17, CIFAR-10 Batch 4:  The Loss is 0.115815
# The Validation Accuracy is 0.6508
# Epoch 17, CIFAR-10 Batch 5:  The Loss is 0.101294
# The Validation Accuracy is 0.659
# Epoch 18, CIFAR-10 Batch 1:  The Loss is 0.107424
# The Validation Accuracy is 0.6402
# Epoch 18, CIFAR-10 Batch 2:  The Loss is 0.144653
# The Validation Accuracy is 0.64
# Epoch 18, CIFAR-10 Batch 3:  The Loss is 0.109782
# The Validation Accuracy is 0.6338
# Epoch 18, CIFAR-10 Batch 4:  The Loss is 0.101228
# The Validation Accuracy is 0.6392
# Epoch 18, CIFAR-10 Batch 5:  The Loss is 0.0900925
# The Validation Accuracy is 0.652
# Epoch 19, CIFAR-10 Batch 1:  The Loss is 0.100088
# The Validation Accuracy is 0.6542
# Epoch 19, CIFAR-10 Batch 2:  The Loss is 0.147349
# The Validation Accuracy is 0.6102
# Epoch 19, CIFAR-10 Batch 3:  The Loss is 0.0810033
# The Validation Accuracy is 0.649
# Epoch 19, CIFAR-10 Batch 4:  The Loss is 0.107247
# The Validation Accuracy is 0.6218
# Epoch 19, CIFAR-10 Batch 5:  The Loss is 0.078881
# The Validation Accuracy is 0.6422
# Epoch 20, CIFAR-10 Batch 1:  The Loss is 0.09212
# The Validation Accuracy is 0.6304
# Epoch 20, CIFAR-10 Batch 2:  The Loss is 0.0833964
# The Validation Accuracy is 0.6326
# Epoch 20, CIFAR-10 Batch 3:  The Loss is 0.0630495
# The Validation Accuracy is 0.6502
# Epoch 20, CIFAR-10 Batch 4:  The Loss is 0.0767713
# The Validation Accuracy is 0.646
# Epoch 20, CIFAR-10 Batch 5:  The Loss is 0.0766926
# The Validation Accuracy is 0.636
# Epoch 21, CIFAR-10 Batch 1:  The Loss is 0.0553659
# The Validation Accuracy is 0.6504
# Epoch 21, CIFAR-10 Batch 2:  The Loss is 0.0954892
# The Validation Accuracy is 0.6348
# Epoch 21, CIFAR-10 Batch 3:  The Loss is 0.0549801
# The Validation Accuracy is 0.6378
# Epoch 21, CIFAR-10 Batch 4:  The Loss is 0.0829211
# The Validation Accuracy is 0.6152
# Epoch 21, CIFAR-10 Batch 5:  The Loss is 0.0397173
# The Validation Accuracy is 0.6498
# Epoch 22, CIFAR-10 Batch 1:  The Loss is 0.0484309
# The Validation Accuracy is 0.6542
# Epoch 22, CIFAR-10 Batch 2:  The Loss is 0.0815227
# The Validation Accuracy is 0.6346
# Epoch 22, CIFAR-10 Batch 3:  The Loss is 0.0513134
# The Validation Accuracy is 0.643
# Epoch 22, CIFAR-10 Batch 4:  The Loss is 0.0596247
# The Validation Accuracy is 0.621
# Epoch 22, CIFAR-10 Batch 5:  The Loss is 0.0797015
# The Validation Accuracy is 0.6364
# Epoch 23, CIFAR-10 Batch 1:  The Loss is 0.0456243
# The Validation Accuracy is 0.6338
# Epoch 23, CIFAR-10 Batch 2:  The Loss is 0.0453767
# The Validation Accuracy is 0.6376
# Epoch 23, CIFAR-10 Batch 3:  The Loss is 0.0369028
# The Validation Accuracy is 0.6452
# Epoch 23, CIFAR-10 Batch 4:  The Loss is 0.0460176
# The Validation Accuracy is 0.6312
# Epoch 23, CIFAR-10 Batch 5:  The Loss is 0.0601925
# The Validation Accuracy is 0.6406
# Epoch 24, CIFAR-10 Batch 1:  The Loss is 0.059072
# The Validation Accuracy is 0.63
# Epoch 24, CIFAR-10 Batch 2:  The Loss is 0.0239734
# The Validation Accuracy is 0.6552
# Epoch 24, CIFAR-10 Batch 3:  The Loss is 0.0231822
# The Validation Accuracy is 0.6502
# Epoch 24, CIFAR-10 Batch 4:  The Loss is 0.0189043
# The Validation Accuracy is 0.6488
# Epoch 24, CIFAR-10 Batch 5:  The Loss is 0.0295837
# The Validation Accuracy is 0.6534
# Epoch 25, CIFAR-10 Batch 1:  The Loss is 0.0365546
# The Validation Accuracy is 0.643
# Epoch 25, CIFAR-10 Batch 2:  The Loss is 0.031755
# The Validation Accuracy is 0.6464
# Epoch 25, CIFAR-10 Batch 3:  The Loss is 0.0271956
# The Validation Accuracy is 0.6382
# Epoch 25, CIFAR-10 Batch 4:  The Loss is 0.0196611
# The Validation Accuracy is 0.6464
# Epoch 25, CIFAR-10 Batch 5:  The Loss is 0.013018
# The Validation Accuracy is 0.6626
# Epoch 26, CIFAR-10 Batch 1:  The Loss is 0.0147459
# The Validation Accuracy is 0.6648
# Epoch 26, CIFAR-10 Batch 2:  The Loss is 0.029923
# The Validation Accuracy is 0.6476
# Epoch 26, CIFAR-10 Batch 3:  The Loss is 0.0296214
# The Validation Accuracy is 0.6336
# Epoch 26, CIFAR-10 Batch 4:  The Loss is 0.0147243
# The Validation Accuracy is 0.651
# Epoch 26, CIFAR-10 Batch 5:  The Loss is 0.0119886
# The Validation Accuracy is 0.6454
# Epoch 27, CIFAR-10 Batch 1:  The Loss is 0.0252612
# The Validation Accuracy is 0.658
# Epoch 27, CIFAR-10 Batch 2:  The Loss is 0.0284633
# The Validation Accuracy is 0.634
# Epoch 27, CIFAR-10 Batch 3:  The Loss is 0.0107026
# The Validation Accuracy is 0.6514
# Epoch 27, CIFAR-10 Batch 4:  The Loss is 0.0155757
# The Validation Accuracy is 0.6478
# Epoch 27, CIFAR-10 Batch 5:  The Loss is 0.0137505
# The Validation Accuracy is 0.6558
# Epoch 28, CIFAR-10 Batch 1:  The Loss is 0.00812598
# The Validation Accuracy is 0.6592
# Epoch 28, CIFAR-10 Batch 2:  The Loss is 0.011167
# The Validation Accuracy is 0.6412
# Epoch 28, CIFAR-10 Batch 3:  The Loss is 0.0150053
# The Validation Accuracy is 0.6344
# Epoch 28, CIFAR-10 Batch 4:  The Loss is 0.010761
# The Validation Accuracy is 0.6502
# Epoch 28, CIFAR-10 Batch 5:  The Loss is 0.00698499
# The Validation Accuracy is 0.6524
# Epoch 29, CIFAR-10 Batch 1:  The Loss is 0.00747263
# The Validation Accuracy is 0.6624
# Epoch 29, CIFAR-10 Batch 2:  The Loss is 0.00860272
# The Validation Accuracy is 0.6388
# Epoch 29, CIFAR-10 Batch 3:  The Loss is 0.00480036
# The Validation Accuracy is 0.6512
# Epoch 29, CIFAR-10 Batch 4:  The Loss is 0.0164837
# The Validation Accuracy is 0.6286
# Epoch 29, CIFAR-10 Batch 5:  The Loss is 0.013085
# The Validation Accuracy is 0.6508
# Epoch 30, CIFAR-10 Batch 1:  The Loss is 0.00908484
# The Validation Accuracy is 0.6476
# Epoch 30, CIFAR-10 Batch 2:  The Loss is 0.0104009
# The Validation Accuracy is 0.6384
# Epoch 30, CIFAR-10 Batch 3:  The Loss is 0.00790175
# The Validation Accuracy is 0.6572
# Epoch 30, CIFAR-10 Batch 4:  The Loss is 0.00661491
# The Validation Accuracy is 0.6518
# Epoch 30, CIFAR-10 Batch 5:  The Loss is 0.00320595
# The Validation Accuracy is 0.6604
# Epoch 31, CIFAR-10 Batch 1:  The Loss is 0.0116268
# The Validation Accuracy is 0.644
# Epoch 31, CIFAR-10 Batch 2:  The Loss is 0.00566861
# The Validation Accuracy is 0.6438
# Epoch 31, CIFAR-10 Batch 3:  The Loss is 0.00599263
# The Validation Accuracy is 0.6592
# Epoch 31, CIFAR-10 Batch 4:  The Loss is 0.00708877
# The Validation Accuracy is 0.6532
# Epoch 31, CIFAR-10 Batch 5:  The Loss is 0.0155948
# The Validation Accuracy is 0.6448
# Epoch 32, CIFAR-10 Batch 1:  The Loss is 0.00897344
# The Validation Accuracy is 0.6504
# Epoch 32, CIFAR-10 Batch 2:  The Loss is 0.0106105
# The Validation Accuracy is 0.6392
# Epoch 32, CIFAR-10 Batch 3:  The Loss is 0.00574305
# The Validation Accuracy is 0.6512
# Epoch 32, CIFAR-10 Batch 4:  The Loss is 0.00272875
# The Validation Accuracy is 0.6646
# Epoch 32, CIFAR-10 Batch 5:  The Loss is 0.00567948
# The Validation Accuracy is 0.6506
# Epoch 33, CIFAR-10 Batch 1:  The Loss is 0.00191009
# The Validation Accuracy is 0.6516
# Epoch 33, CIFAR-10 Batch 2:  The Loss is 0.00358105
# The Validation Accuracy is 0.6508
# Epoch 33, CIFAR-10 Batch 3:  The Loss is 0.00363882
# The Validation Accuracy is 0.657
# Epoch 33, CIFAR-10 Batch 4:  The Loss is 0.00611275
# The Validation Accuracy is 0.6524
# Epoch 33, CIFAR-10 Batch 5:  The Loss is 0.00309535
# The Validation Accuracy is 0.6574
# Epoch 34, CIFAR-10 Batch 1:  The Loss is 0.00347497
# The Validation Accuracy is 0.6552
# Epoch 34, CIFAR-10 Batch 2:  The Loss is 0.00445272
# The Validation Accuracy is 0.6504
# Epoch 34, CIFAR-10 Batch 3:  The Loss is 0.00668847
# The Validation Accuracy is 0.6522
# Epoch 34, CIFAR-10 Batch 4:  The Loss is 0.00234164
# The Validation Accuracy is 0.6494
# Epoch 34, CIFAR-10 Batch 5:  The Loss is 0.00243253
# The Validation Accuracy is 0.6578
# Epoch 35, CIFAR-10 Batch 1:  The Loss is 0.00159938
# The Validation Accuracy is 0.6546
# Epoch 35, CIFAR-10 Batch 2:  The Loss is 0.00168015
# The Validation Accuracy is 0.6532
# Epoch 35, CIFAR-10 Batch 3:  The Loss is 0.00140273
# The Validation Accuracy is 0.659
# Epoch 35, CIFAR-10 Batch 4:  The Loss is 0.00198724
# The Validation Accuracy is 0.6606
# Epoch 35, CIFAR-10 Batch 5:  The Loss is 0.00219217
# The Validation Accuracy is 0.6566
# Epoch 36, CIFAR-10 Batch 1:  The Loss is 0.00347507
# The Validation Accuracy is 0.6602
# Epoch 36, CIFAR-10 Batch 2:  The Loss is 0.00280576
# The Validation Accuracy is 0.6456
# Epoch 36, CIFAR-10 Batch 3:  The Loss is 0.00178102
# The Validation Accuracy is 0.6572
# Epoch 36, CIFAR-10 Batch 4:  The Loss is 0.0039961
# The Validation Accuracy is 0.6538
# Epoch 36, CIFAR-10 Batch 5:  The Loss is 0.00139388
# The Validation Accuracy is 0.6554
# Epoch 37, CIFAR-10 Batch 1:  The Loss is 0.00155005
# The Validation Accuracy is 0.6626
# Epoch 37, CIFAR-10 Batch 2:  The Loss is 0.0037364
# The Validation Accuracy is 0.6488
# Epoch 37, CIFAR-10 Batch 3:  The Loss is 0.00269579
# The Validation Accuracy is 0.6562
# Epoch 37, CIFAR-10 Batch 4:  The Loss is 0.00173853
# The Validation Accuracy is 0.653
# Epoch 37, CIFAR-10 Batch 5:  The Loss is 0.00300386
# The Validation Accuracy is 0.6566
# Epoch 38, CIFAR-10 Batch 1:  The Loss is 0.00331122
# The Validation Accuracy is 0.6614
# Epoch 38, CIFAR-10 Batch 2:  The Loss is 0.00580185
# The Validation Accuracy is 0.6424
# Epoch 38, CIFAR-10 Batch 3:  The Loss is 0.00661678
# The Validation Accuracy is 0.6492
# Epoch 38, CIFAR-10 Batch 4:  The Loss is 0.00313884
# The Validation Accuracy is 0.6574
# Epoch 38, CIFAR-10 Batch 5:  The Loss is 0.000935872
# The Validation Accuracy is 0.6546
# Epoch 39, CIFAR-10 Batch 1:  The Loss is 0.00137906
# The Validation Accuracy is 0.652
# Epoch 39, CIFAR-10 Batch 2:  The Loss is 0.000937119
# The Validation Accuracy is 0.653
# Epoch 39, CIFAR-10 Batch 3:  The Loss is 0.00122595
# The Validation Accuracy is 0.6556
# Epoch 39, CIFAR-10 Batch 4:  The Loss is 0.00199424
# The Validation Accuracy is 0.6596
# Epoch 39, CIFAR-10 Batch 5:  The Loss is 0.00192373
# The Validation Accuracy is 0.6538
# Epoch 40, CIFAR-10 Batch 1:  The Loss is 0.00077158
# The Validation Accuracy is 0.6646
# Epoch 40, CIFAR-10 Batch 2:  The Loss is 0.000973488
# The Validation Accuracy is 0.6598
# Epoch 40, CIFAR-10 Batch 3:  The Loss is 0.00360925
# The Validation Accuracy is 0.6602
# Epoch 40, CIFAR-10 Batch 4:  The Loss is 0.00218962
# The Validation Accuracy is 0.6616
# Epoch 40, CIFAR-10 Batch 5:  The Loss is 0.00178232
# The Validation Accuracy is 0.6622
# Epoch 41, CIFAR-10 Batch 1:  The Loss is 0.0024245
# The Validation Accuracy is 0.66
# Epoch 41, CIFAR-10 Batch 2:  The Loss is 0.00163082
# The Validation Accuracy is 0.65
# Epoch 41, CIFAR-10 Batch 3:  The Loss is 0.00285727
# The Validation Accuracy is 0.6618
# Epoch 41, CIFAR-10 Batch 4:  The Loss is 0.00213887
# The Validation Accuracy is 0.6546
# Epoch 41, CIFAR-10 Batch 5:  The Loss is 0.00125589
# The Validation Accuracy is 0.6636
# Epoch 42, CIFAR-10 Batch 1:  The Loss is 0.000916392
# The Validation Accuracy is 0.6648
# Epoch 42, CIFAR-10 Batch 2:  The Loss is 0.000627189
# The Validation Accuracy is 0.661
# Epoch 42, CIFAR-10 Batch 3:  The Loss is 0.00154199
# The Validation Accuracy is 0.6616
# Epoch 42, CIFAR-10 Batch 4:  The Loss is 0.00139243
# The Validation Accuracy is 0.6614
# Epoch 42, CIFAR-10 Batch 5:  The Loss is 0.00151238
# The Validation Accuracy is 0.6586
# Epoch 43, CIFAR-10 Batch 1:  The Loss is 0.00140413
# The Validation Accuracy is 0.6634
# Epoch 43, CIFAR-10 Batch 2:  The Loss is 0.00101546
# The Validation Accuracy is 0.6608
# Epoch 43, CIFAR-10 Batch 3:  The Loss is 0.00060982
# The Validation Accuracy is 0.6524
# Epoch 43, CIFAR-10 Batch 4:  The Loss is 0.00209662
# The Validation Accuracy is 0.653
# Epoch 43, CIFAR-10 Batch 5:  The Loss is 0.00088018
# The Validation Accuracy is 0.6658
# Epoch 44, CIFAR-10 Batch 1:  The Loss is 0.00183245
# The Validation Accuracy is 0.6722
# Epoch 44, CIFAR-10 Batch 2:  The Loss is 0.00154495
# The Validation Accuracy is 0.6586
# Epoch 44, CIFAR-10 Batch 3:  The Loss is 0.000844373
# The Validation Accuracy is 0.6572
# Epoch 44, CIFAR-10 Batch 4:  The Loss is 0.00102492
# The Validation Accuracy is 0.6594
# Epoch 44, CIFAR-10 Batch 5:  The Loss is 0.00196267
# The Validation Accuracy is 0.6606
# Epoch 45, CIFAR-10 Batch 1:  The Loss is 0.000823214
# The Validation Accuracy is 0.6632
# Epoch 45, CIFAR-10 Batch 2:  The Loss is 0.000714937
# The Validation Accuracy is 0.6594
# Epoch 45, CIFAR-10 Batch 3:  The Loss is 0.00110938
# The Validation Accuracy is 0.659
# Epoch 45, CIFAR-10 Batch 4:  The Loss is 0.00103012
# The Validation Accuracy is 0.6628
# Epoch 45, CIFAR-10 Batch 5:  The Loss is 0.00067331
# The Validation Accuracy is 0.6584
# Epoch 46, CIFAR-10 Batch 1:  The Loss is 0.0016675
# The Validation Accuracy is 0.6678
# Epoch 46, CIFAR-10 Batch 2:  The Loss is 0.000874029
# The Validation Accuracy is 0.654
# Epoch 46, CIFAR-10 Batch 3:  The Loss is 0.0017308
# The Validation Accuracy is 0.6702
# Epoch 46, CIFAR-10 Batch 4:  The Loss is 0.000330187
# The Validation Accuracy is 0.6676
# Epoch 46, CIFAR-10 Batch 5:  The Loss is 0.00124332
# The Validation Accuracy is 0.6648
# Epoch 47, CIFAR-10 Batch 1:  The Loss is 0.000588192
# The Validation Accuracy is 0.672
# Epoch 47, CIFAR-10 Batch 2:  The Loss is 0.000815736
# The Validation Accuracy is 0.6666
# Epoch 47, CIFAR-10 Batch 3:  The Loss is 0.000631436
# The Validation Accuracy is 0.6634
# Epoch 47, CIFAR-10 Batch 4:  The Loss is 0.00067348
# The Validation Accuracy is 0.6616
# Epoch 47, CIFAR-10 Batch 5:  The Loss is 0.00170978
# The Validation Accuracy is 0.6626
# Epoch 48, CIFAR-10 Batch 1:  The Loss is 0.0011697
# The Validation Accuracy is 0.667
# Epoch 48, CIFAR-10 Batch 2:  The Loss is 0.00214245
# The Validation Accuracy is 0.6588
# Epoch 48, CIFAR-10 Batch 3:  The Loss is 0.000476867
# The Validation Accuracy is 0.6636
# Epoch 48, CIFAR-10 Batch 4:  The Loss is 0.00110893
# The Validation Accuracy is 0.6588
# Epoch 48, CIFAR-10 Batch 5:  The Loss is 0.000590855
# The Validation Accuracy is 0.6654
# Epoch 49, CIFAR-10 Batch 1:  The Loss is 0.00123467
# The Validation Accuracy is 0.6586
# Epoch 49, CIFAR-10 Batch 2:  The Loss is 0.000606537
# The Validation Accuracy is 0.6652
# Epoch 49, CIFAR-10 Batch 3:  The Loss is 0.000592036
# The Validation Accuracy is 0.6686
# Epoch 49, CIFAR-10 Batch 4:  The Loss is 0.000575542
# The Validation Accuracy is 0.6678
# Epoch 49, CIFAR-10 Batch 5:  The Loss is 0.00236468
# The Validation Accuracy is 0.6646
# Epoch 50, CIFAR-10 Batch 1:  The Loss is 0.00204343
# The Validation Accuracy is 0.6602
# Epoch 50, CIFAR-10 Batch 2:  The Loss is 0.000815998
# The Validation Accuracy is 0.653
# Epoch 50, CIFAR-10 Batch 3:  The Loss is 0.00127691
# The Validation Accuracy is 0.6584
# Epoch 50, CIFAR-10 Batch 4:  The Loss is 0.000572441
# The Validation Accuracy is 0.666
# Epoch 50, CIFAR-10 Batch 5:  The Loss is 0.000739227
# The Validation Accuracy is 0.6618
# Epoch 51, CIFAR-10 Batch 1:  The Loss is 0.000580555
# The Validation Accuracy is 0.6666
# Epoch 51, CIFAR-10 Batch 2:  The Loss is 0.000645005
# The Validation Accuracy is 0.6692
# Epoch 51, CIFAR-10 Batch 3:  The Loss is 0.000388416
# The Validation Accuracy is 0.6666
# Epoch 51, CIFAR-10 Batch 4:  The Loss is 0.000848975
# The Validation Accuracy is 0.6606
# Epoch 51, CIFAR-10 Batch 5:  The Loss is 0.000581075
# The Validation Accuracy is 0.664
# Epoch 52, CIFAR-10 Batch 1:  The Loss is 0.000993945
# The Validation Accuracy is 0.6646
# Epoch 52, CIFAR-10 Batch 2:  The Loss is 0.000932512
# The Validation Accuracy is 0.6668
# Epoch 52, CIFAR-10 Batch 3:  The Loss is 0.000843077
# The Validation Accuracy is 0.661
# Epoch 52, CIFAR-10 Batch 4:  The Loss is 0.000631528
# The Validation Accuracy is 0.6684
# Epoch 52, CIFAR-10 Batch 5:  The Loss is 0.00122341
# The Validation Accuracy is 0.6622
# Epoch 53, CIFAR-10 Batch 1:  The Loss is 0.00097511
# The Validation Accuracy is 0.6616
# Epoch 53, CIFAR-10 Batch 2:  The Loss is 0.000676464
# The Validation Accuracy is 0.6532
# Epoch 53, CIFAR-10 Batch 3:  The Loss is 0.000841324
# The Validation Accuracy is 0.6566
# Epoch 53, CIFAR-10 Batch 4:  The Loss is 0.00137041
# The Validation Accuracy is 0.6564
# Epoch 53, CIFAR-10 Batch 5:  The Loss is 0.000277864
# The Validation Accuracy is 0.6592
# Epoch 54, CIFAR-10 Batch 1:  The Loss is 0.000464467
# The Validation Accuracy is 0.6602
# Epoch 54, CIFAR-10 Batch 2:  The Loss is 0.00118374
# The Validation Accuracy is 0.6612
# Epoch 54, CIFAR-10 Batch 3:  The Loss is 0.0069119
# The Validation Accuracy is 0.656
# Epoch 54, CIFAR-10 Batch 4:  The Loss is 0.00143867
# The Validation Accuracy is 0.6632
# Epoch 54, CIFAR-10 Batch 5:  The Loss is 0.000619402
# The Validation Accuracy is 0.655
# Epoch 55, CIFAR-10 Batch 1:  The Loss is 0.00228833
# The Validation Accuracy is 0.6602
# Epoch 55, CIFAR-10 Batch 2:  The Loss is 0.000754366
# The Validation Accuracy is 0.6626
# Epoch 55, CIFAR-10 Batch 3:  The Loss is 0.000381023
# The Validation Accuracy is 0.6564
# Epoch 55, CIFAR-10 Batch 4:  The Loss is 0.00336758
# The Validation Accuracy is 0.6532
# Epoch 55, CIFAR-10 Batch 5:  The Loss is 0.000481199
# The Validation Accuracy is 0.6668
# Epoch 56, CIFAR-10 Batch 1:  The Loss is 0.00460821
# The Validation Accuracy is 0.6612
# Epoch 56, CIFAR-10 Batch 2:  The Loss is 0.000743646
# The Validation Accuracy is 0.6592
# Epoch 56, CIFAR-10 Batch 3:  The Loss is 0.000266716
# The Validation Accuracy is 0.6638
# Epoch 56, CIFAR-10 Batch 4:  The Loss is 0.00221661
# The Validation Accuracy is 0.6608
# Epoch 56, CIFAR-10 Batch 5:  The Loss is 0.000535192
# The Validation Accuracy is 0.6706
# Epoch 57, CIFAR-10 Batch 1:  The Loss is 0.00164589
# The Validation Accuracy is 0.656
# Epoch 57, CIFAR-10 Batch 2:  The Loss is 0.00318352
# The Validation Accuracy is 0.6628
# Epoch 57, CIFAR-10 Batch 3:  The Loss is 0.00163688
# The Validation Accuracy is 0.6548
# Epoch 57, CIFAR-10 Batch 4:  The Loss is 0.000542733
# The Validation Accuracy is 0.649
# Epoch 57, CIFAR-10 Batch 5:  The Loss is 0.000712737
# The Validation Accuracy is 0.6604
# Epoch 58, CIFAR-10 Batch 1:  The Loss is 0.000764723
# The Validation Accuracy is 0.6626
# Epoch 58, CIFAR-10 Batch 2:  The Loss is 0.000850448
# The Validation Accuracy is 0.6568
# Epoch 58, CIFAR-10 Batch 3:  The Loss is 0.000420234
# The Validation Accuracy is 0.6554
# Epoch 58, CIFAR-10 Batch 4:  The Loss is 0.000459002
# The Validation Accuracy is 0.6566
# Epoch 58, CIFAR-10 Batch 5:  The Loss is 0.000280291
# The Validation Accuracy is 0.6588
# Epoch 59, CIFAR-10 Batch 1:  The Loss is 0.00148046
# The Validation Accuracy is 0.6588
# Epoch 59, CIFAR-10 Batch 2:  The Loss is 0.000468118
# The Validation Accuracy is 0.6588
# Epoch 59, CIFAR-10 Batch 3:  The Loss is 0.000139347
# The Validation Accuracy is 0.6556
# Epoch 59, CIFAR-10 Batch 4:  The Loss is 0.00403257
# The Validation Accuracy is 0.6518
# Epoch 59, CIFAR-10 Batch 5:  The Loss is 0.001669
# The Validation Accuracy is 0.652
# Epoch 60, CIFAR-10 Batch 1:  The Loss is 0.00160102
# The Validation Accuracy is 0.6578
# Epoch 60, CIFAR-10 Batch 2:  The Loss is 0.000563737
# The Validation Accuracy is 0.663
# Epoch 60, CIFAR-10 Batch 3:  The Loss is 0.00264901
# The Validation Accuracy is 0.6524
# Epoch 60, CIFAR-10 Batch 4:  The Loss is 0.000837407
# The Validation Accuracy is 0.6556
# Epoch 60, CIFAR-10 Batch 5:  The Loss is 0.000865498
# The Validation Accuracy is 0.6602
# Epoch 61, CIFAR-10 Batch 1:  The Loss is 0.00138282
# The Validation Accuracy is 0.6602
# Epoch 61, CIFAR-10 Batch 2:  The Loss is 0.000613805
# The Validation Accuracy is 0.661
# Epoch 61, CIFAR-10 Batch 3:  The Loss is 0.000791797
# The Validation Accuracy is 0.663
# Epoch 61, CIFAR-10 Batch 4:  The Loss is 0.000866764
# The Validation Accuracy is 0.6658
# Epoch 61, CIFAR-10 Batch 5:  The Loss is 0.000343089
# The Validation Accuracy is 0.6566
# Epoch 62, CIFAR-10 Batch 1:  The Loss is 0.00122244
# The Validation Accuracy is 0.6676
# Epoch 62, CIFAR-10 Batch 2:  The Loss is 0.000366818
# The Validation Accuracy is 0.6638
# Epoch 62, CIFAR-10 Batch 3:  The Loss is 0.000712734
# The Validation Accuracy is 0.662
# Epoch 62, CIFAR-10 Batch 4:  The Loss is 0.000395501
# The Validation Accuracy is 0.6678
# Epoch 62, CIFAR-10 Batch 5:  The Loss is 0.00121562
# The Validation Accuracy is 0.6458
# Epoch 63, CIFAR-10 Batch 1:  The Loss is 0.000449048
# The Validation Accuracy is 0.6598
# Epoch 63, CIFAR-10 Batch 2:  The Loss is 0.000553772
# The Validation Accuracy is 0.6656
# Epoch 63, CIFAR-10 Batch 3:  The Loss is 0.000222794
# The Validation Accuracy is 0.6622
# Epoch 63, CIFAR-10 Batch 4:  The Loss is 0.000422916
# The Validation Accuracy is 0.6644
# Epoch 63, CIFAR-10 Batch 5:  The Loss is 0.00310228
# The Validation Accuracy is 0.6408
# Epoch 64, CIFAR-10 Batch 1:  The Loss is 0.000274804
# The Validation Accuracy is 0.6658
# Epoch 64, CIFAR-10 Batch 2:  The Loss is 0.000224149
# The Validation Accuracy is 0.6592
# Epoch 64, CIFAR-10 Batch 3:  The Loss is 0.000659799
# The Validation Accuracy is 0.6584
# Epoch 64, CIFAR-10 Batch 4:  The Loss is 0.000528577
# The Validation Accuracy is 0.6616
# Epoch 64, CIFAR-10 Batch 5:  The Loss is 0.000628049
# The Validation Accuracy is 0.6592
# Epoch 65, CIFAR-10 Batch 1:  The Loss is 0.0028689
# The Validation Accuracy is 0.6562
# Epoch 65, CIFAR-10 Batch 2:  The Loss is 0.00332671
# The Validation Accuracy is 0.6542
# Epoch 65, CIFAR-10 Batch 3:  The Loss is 0.000329464
# The Validation Accuracy is 0.6536
# Epoch 65, CIFAR-10 Batch 4:  The Loss is 0.000965738
# The Validation Accuracy is 0.6572
# Epoch 65, CIFAR-10 Batch 5:  The Loss is 0.00488445
# The Validation Accuracy is 0.6504
# Epoch 66, CIFAR-10 Batch 1:  The Loss is 0.000485951
# The Validation Accuracy is 0.6638
# Epoch 66, CIFAR-10 Batch 2:  The Loss is 0.00133316
# The Validation Accuracy is 0.6646
# Epoch 66, CIFAR-10 Batch 3:  The Loss is 0.00342616
# The Validation Accuracy is 0.6556
# Epoch 66, CIFAR-10 Batch 4:  The Loss is 0.000214581
# The Validation Accuracy is 0.6618
# Epoch 66, CIFAR-10 Batch 5:  The Loss is 0.000585452
# The Validation Accuracy is 0.6492
# Epoch 67, CIFAR-10 Batch 1:  The Loss is 0.00190208
# The Validation Accuracy is 0.6556
# Epoch 67, CIFAR-10 Batch 2:  The Loss is 0.000785684
# The Validation Accuracy is 0.6634
# Epoch 67, CIFAR-10 Batch 3:  The Loss is 0.00117971
# The Validation Accuracy is 0.6514
# Epoch 67, CIFAR-10 Batch 4:  The Loss is 0.000920147
# The Validation Accuracy is 0.6584
# Epoch 67, CIFAR-10 Batch 5:  The Loss is 0.000543284
# The Validation Accuracy is 0.6578
# Epoch 68, CIFAR-10 Batch 1:  The Loss is 0.000894188
# The Validation Accuracy is 0.662
# Epoch 68, CIFAR-10 Batch 2:  The Loss is 0.000582222
# The Validation Accuracy is 0.6618
# Epoch 68, CIFAR-10 Batch 3:  The Loss is 0.00478834
# The Validation Accuracy is 0.6582
# Epoch 68, CIFAR-10 Batch 4:  The Loss is 0.00275237
# The Validation Accuracy is 0.6676
# Epoch 68, CIFAR-10 Batch 5:  The Loss is 0.000779447
# The Validation Accuracy is 0.652
# Epoch 69, CIFAR-10 Batch 1:  The Loss is 0.00307124
# The Validation Accuracy is 0.656
# Epoch 69, CIFAR-10 Batch 2:  The Loss is 0.000355106
# The Validation Accuracy is 0.661
# Epoch 69, CIFAR-10 Batch 3:  The Loss is 0.000104454
# The Validation Accuracy is 0.6692
# Epoch 69, CIFAR-10 Batch 4:  The Loss is 0.00356206
# The Validation Accuracy is 0.6584
# Epoch 69, CIFAR-10 Batch 5:  The Loss is 0.000651932
# The Validation Accuracy is 0.6636
# Epoch 70, CIFAR-10 Batch 1:  The Loss is 0.00379682
# The Validation Accuracy is 0.655
# Epoch 70, CIFAR-10 Batch 2:  The Loss is 0.000446498
# The Validation Accuracy is 0.657
# Epoch 70, CIFAR-10 Batch 3:  The Loss is 0.0014266
# The Validation Accuracy is 0.651
# Epoch 70, CIFAR-10 Batch 4:  The Loss is 0.000940646
# The Validation Accuracy is 0.6554
# Epoch 70, CIFAR-10 Batch 5:  The Loss is 0.000805963
# The Validation Accuracy is 0.6542
# Epoch 71, CIFAR-10 Batch 1:  The Loss is 0.000828993
# The Validation Accuracy is 0.665
# Epoch 71, CIFAR-10 Batch 2:  The Loss is 0.000597229
# The Validation Accuracy is 0.6602
# Epoch 71, CIFAR-10 Batch 3:  The Loss is 0.000312117
# The Validation Accuracy is 0.6684
# Epoch 71, CIFAR-10 Batch 4:  The Loss is 0.000408671
# The Validation Accuracy is 0.6674
# Epoch 71, CIFAR-10 Batch 5:  The Loss is 0.000456985
# The Validation Accuracy is 0.654
# Epoch 72, CIFAR-10 Batch 1:  The Loss is 0.000553143
# The Validation Accuracy is 0.6616
# Epoch 72, CIFAR-10 Batch 2:  The Loss is 0.000460346
# The Validation Accuracy is 0.6618
# Epoch 72, CIFAR-10 Batch 3:  The Loss is 0.00140264
# The Validation Accuracy is 0.659
# Epoch 72, CIFAR-10 Batch 4:  The Loss is 0.00254154
# The Validation Accuracy is 0.6546
# Epoch 72, CIFAR-10 Batch 5:  The Loss is 0.00136491
# The Validation Accuracy is 0.642
# Epoch 73, CIFAR-10 Batch 1:  The Loss is 0.000672186
# The Validation Accuracy is 0.6578
# Epoch 73, CIFAR-10 Batch 2:  The Loss is 0.000644307
# The Validation Accuracy is 0.6548
# Epoch 73, CIFAR-10 Batch 3:  The Loss is 0.000145612
# The Validation Accuracy is 0.6648
# Epoch 73, CIFAR-10 Batch 4:  The Loss is 0.00100156
# The Validation Accuracy is 0.656
# Epoch 73, CIFAR-10 Batch 5:  The Loss is 0.00242898
# The Validation Accuracy is 0.6522
# Epoch 74, CIFAR-10 Batch 1:  The Loss is 0.00155381
# The Validation Accuracy is 0.6408
# Epoch 74, CIFAR-10 Batch 2:  The Loss is 0.00251369
# The Validation Accuracy is 0.6526
# Epoch 74, CIFAR-10 Batch 3:  The Loss is 0.000219411
# The Validation Accuracy is 0.6618
# Epoch 74, CIFAR-10 Batch 4:  The Loss is 0.000347191
# The Validation Accuracy is 0.656
# Epoch 74, CIFAR-10 Batch 5:  The Loss is 0.000335597
# The Validation Accuracy is 0.6578
# Epoch 75, CIFAR-10 Batch 1:  The Loss is 0.00113816
# The Validation Accuracy is 0.6536
# Epoch 75, CIFAR-10 Batch 2:  The Loss is 0.000327793
# The Validation Accuracy is 0.6546
# Epoch 75, CIFAR-10 Batch 3:  The Loss is 0.000386225
# The Validation Accuracy is 0.6674
# Epoch 75, CIFAR-10 Batch 4:  The Loss is 0.000429427
# The Validation Accuracy is 0.664
# Epoch 75, CIFAR-10 Batch 5:  The Loss is 0.00114783
# The Validation Accuracy is 0.6546
# Epoch 76, CIFAR-10 Batch 1:  The Loss is 0.000437133
# The Validation Accuracy is 0.6676
# Epoch 76, CIFAR-10 Batch 2:  The Loss is 0.000252263
# The Validation Accuracy is 0.6678
# Epoch 76, CIFAR-10 Batch 3:  The Loss is 0.000255036
# The Validation Accuracy is 0.6584
# Epoch 76, CIFAR-10 Batch 4:  The Loss is 0.000661338
# The Validation Accuracy is 0.655
# Epoch 76, CIFAR-10 Batch 5:  The Loss is 0.00073776
# The Validation Accuracy is 0.655
# Epoch 77, CIFAR-10 Batch 1:  The Loss is 0.00146844
# The Validation Accuracy is 0.6692
# Epoch 77, CIFAR-10 Batch 2:  The Loss is 0.000954599
# The Validation Accuracy is 0.6466
# Epoch 77, CIFAR-10 Batch 3:  The Loss is 0.00365704
# The Validation Accuracy is 0.651
# Epoch 77, CIFAR-10 Batch 4:  The Loss is 0.00024716
# The Validation Accuracy is 0.6674
# Epoch 77, CIFAR-10 Batch 5:  The Loss is 0.000831899
# The Validation Accuracy is 0.6708
# Epoch 78, CIFAR-10 Batch 1:  The Loss is 0.00071835
# The Validation Accuracy is 0.6614
# Epoch 78, CIFAR-10 Batch 2:  The Loss is 0.000374781
# The Validation Accuracy is 0.6558
# Epoch 78, CIFAR-10 Batch 3:  The Loss is 0.000118803
# The Validation Accuracy is 0.6538
# Epoch 78, CIFAR-10 Batch 4:  The Loss is 0.0047964
# The Validation Accuracy is 0.6446
# Epoch 78, CIFAR-10 Batch 5:  The Loss is 0.000339639
# The Validation Accuracy is 0.6562
# Epoch 79, CIFAR-10 Batch 1:  The Loss is 0.00064844
# The Validation Accuracy is 0.646
# Epoch 79, CIFAR-10 Batch 2:  The Loss is 0.00130956
# The Validation Accuracy is 0.6584
# Epoch 79, CIFAR-10 Batch 3:  The Loss is 0.000956007
# The Validation Accuracy is 0.6576
# Epoch 79, CIFAR-10 Batch 4:  The Loss is 0.000539873
# The Validation Accuracy is 0.6664
# Epoch 79, CIFAR-10 Batch 5:  The Loss is 0.000930077
# The Validation Accuracy is 0.6542
# Epoch 80, CIFAR-10 Batch 1:  The Loss is 0.000294562
# The Validation Accuracy is 0.6604
# Epoch 80, CIFAR-10 Batch 2:  The Loss is 7.10718e-05
# The Validation Accuracy is 0.6664
# Epoch 80, CIFAR-10 Batch 3:  The Loss is 0.0014738
# The Validation Accuracy is 0.6554
# Epoch 80, CIFAR-10 Batch 4:  The Loss is 0.000586312
# The Validation Accuracy is 0.6598
# Epoch 80, CIFAR-10 Batch 5:  The Loss is 0.000203291
# The Validation Accuracy is 0.6646
# Epoch 81, CIFAR-10 Batch 1:  The Loss is 0.00185175
# The Validation Accuracy is 0.6642
# Epoch 81, CIFAR-10 Batch 2:  The Loss is 0.000223749
# The Validation Accuracy is 0.6574
# Epoch 81, CIFAR-10 Batch 3:  The Loss is 0.000395757
# The Validation Accuracy is 0.6588
# Epoch 81, CIFAR-10 Batch 4:  The Loss is 0.000191499
# The Validation Accuracy is 0.6532
# Epoch 81, CIFAR-10 Batch 5:  The Loss is 0.00268885
# The Validation Accuracy is 0.6632
# Epoch 82, CIFAR-10 Batch 1:  The Loss is 0.000865336
# The Validation Accuracy is 0.6586
# Epoch 82, CIFAR-10 Batch 2:  The Loss is 0.00157845
# The Validation Accuracy is 0.647
# Epoch 82, CIFAR-10 Batch 3:  The Loss is 0.00179979
# The Validation Accuracy is 0.6454
# Epoch 82, CIFAR-10 Batch 4:  The Loss is 0.000415594
# The Validation Accuracy is 0.6556
# Epoch 82, CIFAR-10 Batch 5:  The Loss is 0.000820388
# The Validation Accuracy is 0.6578
# Epoch 83, CIFAR-10 Batch 1:  The Loss is 0.000303905
# The Validation Accuracy is 0.6542
# Epoch 83, CIFAR-10 Batch 2:  The Loss is 0.00160118
# The Validation Accuracy is 0.643
# Epoch 83, CIFAR-10 Batch 3:  The Loss is 0.00339227
# The Validation Accuracy is 0.638
# Epoch 83, CIFAR-10 Batch 4:  The Loss is 0.00199638
# The Validation Accuracy is 0.651
# Epoch 83, CIFAR-10 Batch 5:  The Loss is 0.000789081
# The Validation Accuracy is 0.6556
# Epoch 84, CIFAR-10 Batch 1:  The Loss is 0.000290251
# The Validation Accuracy is 0.6606
# Epoch 84, CIFAR-10 Batch 2:  The Loss is 0.000103666
# The Validation Accuracy is 0.6584
# Epoch 84, CIFAR-10 Batch 3:  The Loss is 7.653e-05
# The Validation Accuracy is 0.6644
# Epoch 84, CIFAR-10 Batch 4:  The Loss is 0.00114744
# The Validation Accuracy is 0.6578
# Epoch 84, CIFAR-10 Batch 5:  The Loss is 0.000522977
# The Validation Accuracy is 0.6504
# Epoch 85, CIFAR-10 Batch 1:  The Loss is 0.000359427
# The Validation Accuracy is 0.6608
# Epoch 85, CIFAR-10 Batch 2:  The Loss is 8.10895e-05
# The Validation Accuracy is 0.6544
# Epoch 85, CIFAR-10 Batch 3:  The Loss is 0.000180861
# The Validation Accuracy is 0.6546
# Epoch 85, CIFAR-10 Batch 4:  The Loss is 0.000283244
# The Validation Accuracy is 0.6536
# Epoch 85, CIFAR-10 Batch 5:  The Loss is 0.000281218
# The Validation Accuracy is 0.6588
# Epoch 86, CIFAR-10 Batch 1:  The Loss is 0.000605685
# The Validation Accuracy is 0.6594
# Epoch 86, CIFAR-10 Batch 2:  The Loss is 0.000700673
# The Validation Accuracy is 0.653
# Epoch 86, CIFAR-10 Batch 3:  The Loss is 8.30859e-05
# The Validation Accuracy is 0.6514
# Epoch 86, CIFAR-10 Batch 4:  The Loss is 0.000113055
# The Validation Accuracy is 0.65
# Epoch 86, CIFAR-10 Batch 5:  The Loss is 0.000106147
# The Validation Accuracy is 0.656
# Epoch 87, CIFAR-10 Batch 1:  The Loss is 0.000284068
# The Validation Accuracy is 0.652
# Epoch 87, CIFAR-10 Batch 2:  The Loss is 8.69826e-05
# The Validation Accuracy is 0.6566
# Epoch 87, CIFAR-10 Batch 3:  The Loss is 0.000332559
# The Validation Accuracy is 0.6572
# Epoch 87, CIFAR-10 Batch 4:  The Loss is 0.00122187
# The Validation Accuracy is 0.6502
# Epoch 87, CIFAR-10 Batch 5:  The Loss is 0.000397232
# The Validation Accuracy is 0.667
# Epoch 88, CIFAR-10 Batch 1:  The Loss is 0.000262407
# The Validation Accuracy is 0.6672
# Epoch 88, CIFAR-10 Batch 2:  The Loss is 0.000184546
# The Validation Accuracy is 0.6582
# Epoch 88, CIFAR-10 Batch 3:  The Loss is 0.000600629
# The Validation Accuracy is 0.6554
# Epoch 88, CIFAR-10 Batch 4:  The Loss is 0.000520015
# The Validation Accuracy is 0.6586
# Epoch 88, CIFAR-10 Batch 5:  The Loss is 0.000891962
# The Validation Accuracy is 0.6588
# Epoch 89, CIFAR-10 Batch 1:  The Loss is 0.000321405
# The Validation Accuracy is 0.6648
# Epoch 89, CIFAR-10 Batch 2:  The Loss is 0.000502179
# The Validation Accuracy is 0.6522
# Epoch 89, CIFAR-10 Batch 3:  The Loss is 0.00025208
# The Validation Accuracy is 0.6534
# Epoch 89, CIFAR-10 Batch 4:  The Loss is 0.00138044
# The Validation Accuracy is 0.6592
# Epoch 89, CIFAR-10 Batch 5:  The Loss is 0.000596345
# The Validation Accuracy is 0.6714
# Epoch 90, CIFAR-10 Batch 1:  The Loss is 0.000838982
# The Validation Accuracy is 0.6648
# Epoch 90, CIFAR-10 Batch 2:  The Loss is 0.000145788
# The Validation Accuracy is 0.6574
# Epoch 90, CIFAR-10 Batch 3:  The Loss is 0.00117658
# The Validation Accuracy is 0.6598
# Epoch 90, CIFAR-10 Batch 4:  The Loss is 0.000333473
# The Validation Accuracy is 0.6542
# Epoch 90, CIFAR-10 Batch 5:  The Loss is 0.000731388
# The Validation Accuracy is 0.6614
# Epoch 91, CIFAR-10 Batch 1:  The Loss is 0.00115714
# The Validation Accuracy is 0.6602
# Epoch 91, CIFAR-10 Batch 2:  The Loss is 0.000700949
# The Validation Accuracy is 0.6428
# Epoch 91, CIFAR-10 Batch 3:  The Loss is 0.000508563
# The Validation Accuracy is 0.6494
# Epoch 91, CIFAR-10 Batch 4:  The Loss is 0.000329783
# The Validation Accuracy is 0.6514
# Epoch 91, CIFAR-10 Batch 5:  The Loss is 0.000162478
# The Validation Accuracy is 0.6548
# Epoch 92, CIFAR-10 Batch 1:  The Loss is 0.00016627
# The Validation Accuracy is 0.6524
# Epoch 92, CIFAR-10 Batch 2:  The Loss is 0.00182226
# The Validation Accuracy is 0.6512
# Epoch 92, CIFAR-10 Batch 3:  The Loss is 0.00153663
# The Validation Accuracy is 0.6424
# Epoch 92, CIFAR-10 Batch 4:  The Loss is 0.000304853
# The Validation Accuracy is 0.6512
# Epoch 92, CIFAR-10 Batch 5:  The Loss is 0.000175147
# The Validation Accuracy is 0.6566
# Epoch 93, CIFAR-10 Batch 1:  The Loss is 0.000757013
# The Validation Accuracy is 0.659
# Epoch 93, CIFAR-10 Batch 2:  The Loss is 0.00124579
# The Validation Accuracy is 0.6556
# Epoch 93, CIFAR-10 Batch 3:  The Loss is 0.000387025
# The Validation Accuracy is 0.657
# Epoch 93, CIFAR-10 Batch 4:  The Loss is 0.00025812
# The Validation Accuracy is 0.6546
# Epoch 93, CIFAR-10 Batch 5:  The Loss is 0.00181731
# The Validation Accuracy is 0.6608
# Epoch 94, CIFAR-10 Batch 1:  The Loss is 0.00633035
# The Validation Accuracy is 0.652
# Epoch 94, CIFAR-10 Batch 2:  The Loss is 0.00045037
# The Validation Accuracy is 0.651
# Epoch 94, CIFAR-10 Batch 3:  The Loss is 0.00690464
# The Validation Accuracy is 0.6546
# Epoch 94, CIFAR-10 Batch 4:  The Loss is 0.00124969
# The Validation Accuracy is 0.6412
# Epoch 94, CIFAR-10 Batch 5:  The Loss is 0.000106968
# The Validation Accuracy is 0.6608
# Epoch 95, CIFAR-10 Batch 1:  The Loss is 0.00494091
# The Validation Accuracy is 0.648
# Epoch 95, CIFAR-10 Batch 2:  The Loss is 0.000783599
# The Validation Accuracy is 0.6542
# Epoch 95, CIFAR-10 Batch 3:  The Loss is 0.000731104
# The Validation Accuracy is 0.6554
# Epoch 95, CIFAR-10 Batch 4:  The Loss is 0.000401747
# The Validation Accuracy is 0.6504
# Epoch 95, CIFAR-10 Batch 5:  The Loss is 0.00202946
# The Validation Accuracy is 0.6534
# Epoch 96, CIFAR-10 Batch 1:  The Loss is 0.000473586
# The Validation Accuracy is 0.6586
# Epoch 96, CIFAR-10 Batch 2:  The Loss is 0.0012728
# The Validation Accuracy is 0.654
# Epoch 96, CIFAR-10 Batch 3:  The Loss is 0.000150442
# The Validation Accuracy is 0.6568
# Epoch 96, CIFAR-10 Batch 4:  The Loss is 0.000263514
# The Validation Accuracy is 0.6618
# Epoch 96, CIFAR-10 Batch 5:  The Loss is 0.000315988
# The Validation Accuracy is 0.6574
# Epoch 97, CIFAR-10 Batch 1:  The Loss is 0.00120063
# The Validation Accuracy is 0.653
# Epoch 97, CIFAR-10 Batch 2:  The Loss is 0.00202419
# The Validation Accuracy is 0.6566
# Epoch 97, CIFAR-10 Batch 3:  The Loss is 0.00087381
# The Validation Accuracy is 0.6624
# Epoch 97, CIFAR-10 Batch 4:  The Loss is 0.000419184
# The Validation Accuracy is 0.664
# Epoch 97, CIFAR-10 Batch 5:  The Loss is 0.000712195
# The Validation Accuracy is 0.6668
# Epoch 98, CIFAR-10 Batch 1:  The Loss is 0.000770963
# The Validation Accuracy is 0.6588
# Epoch 98, CIFAR-10 Batch 2:  The Loss is 0.000422465
# The Validation Accuracy is 0.6566
# Epoch 98, CIFAR-10 Batch 3:  The Loss is 7.15725e-05
# The Validation Accuracy is 0.6648
# Epoch 98, CIFAR-10 Batch 4:  The Loss is 0.000846669
# The Validation Accuracy is 0.6586
# Epoch 98, CIFAR-10 Batch 5:  The Loss is 0.000311813
# The Validation Accuracy is 0.6712
# Epoch 99, CIFAR-10 Batch 1:  The Loss is 0.000161531
# The Validation Accuracy is 0.6636
# Epoch 99, CIFAR-10 Batch 2:  The Loss is 0.000120752
# The Validation Accuracy is 0.6614
# Epoch 99, CIFAR-10 Batch 3:  The Loss is 0.0010112
# The Validation Accuracy is 0.6536
# Epoch 99, CIFAR-10 Batch 4:  The Loss is 0.000801827
# The Validation Accuracy is 0.6662
# Epoch 99, CIFAR-10 Batch 5:  The Loss is 0.000335929
# The Validation Accuracy is 0.6638
# Epoch 100, CIFAR-10 Batch 1:  The Loss is 0.00071229
# The Validation Accuracy is 0.6602
# Epoch 100, CIFAR-10 Batch 2:  The Loss is 0.00256056
# The Validation Accuracy is 0.6508
# Epoch 100, CIFAR-10 Batch 3:  The Loss is 0.000307932
# The Validation Accuracy is 0.6568
# Epoch 100, CIFAR-10 Batch 4:  The Loss is 0.000204476
# The Validation Accuracy is 0.6636
# Epoch 100, CIFAR-10 Batch 5:  The Loss is 0.000202344
# The Validation Accuracy is 0.6678

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6574850648641586

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
